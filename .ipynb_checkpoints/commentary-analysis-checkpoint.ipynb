# %%
import os,json,io
print ('Getting base directory... ', end='')
base = os.getcwd()
print ('Done\nSetting the base at', base)
# Out:
# Getting base directory... Done
# Setting the base at /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis

# %%
from bs4 import BeautifulSoup as bsp
print ('Changing to the commentary db folder', end='')
os.chdir(os.path.join(base,'commentaries'))
print (os.getcwd(),'... Done')

print('Collecting all matches in current folder...', end='')
matches = [f for f in os.scandir(os.getcwd()) if f.is_dir() and f.name.isdigit()];
print(' Done')
# Out:
# Changing to the commentary db folder/mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries ... Done
# Collecting all matches in current folder... Done

# %%
#test
matches
# Out:
# [<DirEntry '1168514'>,
#  <DirEntry '1153252'>,
#  <DirEntry '1130742'>,
#  <DirEntry '1153846'>,
#  <DirEntry '1146721'>,
#  <DirEntry '1168512'>,
#  <DirEntry '1146720'>,
#  <DirEntry '1168513'>,
#  <DirEntry '1153248'>,
#  <DirEntry '1153845'>,
#  <DirEntry '1146722'>,
#  <DirEntry '1153314'>,
#  <DirEntry '1130741'>,
#  <DirEntry '1153635'>,
#  <DirEntry '1153844'>,
#  <DirEntry '1144491'>,
#  <DirEntry '1153254'>,
#  <DirEntry '1130743'>,
#  <DirEntry '1153249'>,
#  <DirEntry '1153255'>,
#  <DirEntry '1130737'>,
#  <DirEntry '1144487'>,
#  <DirEntry '1153636'>,
#  <DirEntry '1153316'>,
#  <DirEntry '1153315'>,
#  <DirEntry '1153637'>,
#  <DirEntry '1130739'>,
#  <DirEntry '1153243'>,
#  <DirEntry '1168509'>]

# %%
#putting frequently used text in variable, helpful in IDE's with auto completion
t_commentary = 'commentary'
t_items = 'items'
t_shorttext = 'shortText'
t_postText = 'postText'
t_text = 'text'
t_preText = 'preText'

#functions I'll need
#-----------------------------------------get_match_details-----------------------------------------------------
def get_match_details(match_id):
    import requests
    r = requests.get(f'http://www.espncricinfo.com/series/engine/match/{match_id}.json')
    return r.json()
#---------------------------------------------------------------------------------------------------------------
def get_required_innings_value(country):
    pass
    
def get_vader_sentence_score(sentence_string):
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

    scores = SentimentIntensityAnalyzer()

    return scores.polarity_scores(sentence_string)

#----------------------------------------------------------------------------------------------------------------------------
def get_all_text_fromjsonfile(data):
    alltext = ''
    for item in data[t_commentary][t_items]:
        alltext += item[t_preText] + item[t_postText]
    return bsp(alltext, 'lxml').text
#--------------------------------------------------------------------------------------------------------------------
def get_player_score_fromjson(data):
    import nltk, io
    from nltk.tokenize import sent_tokenize, word_tokenize
    from nltk.corpus import stopwords

    def without_stopwords(word_list):
        stopset = set(stopwords.words('english'))
        return [x for x in word_list if x not in stopset]

    players = dict()
#     personal_comm = dict() # run this externally and comment this in the final run
    with io.open(os.path.join(base,'player_names.json'), 'r') as fp:
        players = json.load(fp)
#         print('\n', players,'\n')
        for sent in nltk.sent_tokenize(get_all_text_fromjsonfile(data)):
            print (sent)
            for chunk in nltk.ne_chunk(nltk.pos_tag(without_stopwords(nltk.word_tokenize(sent)))):
                if hasattr(chunk, 'label') and (chunk.label() == 'PERSON'):
                    playerFromSent = ' '.join(c[0] for c in chunk)
                    print(f'\nworking with {playerFromSent}\n')
                    for player in players.keys():
                        if playerFromSent.lower() in players[player]:
                            print (playerFromSent,'found\n')
                            personal_comm.setdefault(player.lower(),[]).append([get_vader_sentence_score(sent)['compound'],sent])
    return personal_comm

# %% [markdown]
# # <span style="color:red;">S U P E R - I M P O R T A N T</span>

# %%
personal_comm = dict()

# %% [markdown]
# ^***run this and comment it in function before final run***

# %%
for match in matches:
    os.chdir(match.path);
    match_details = get_match_details(match.name)
    print ("moving to "+match.path);
    innings = [f.path for f in os.scandir(match.path) if f.is_dir()]
    for single_innings in innings:
        os.chdir(single_innings);
        print ("moving to "+single_innings);
        for jsonfile in os.listdir():
            if 'comm_part' in jsonfile:
                print("opening " + jsonfile)
                with io.open(jsonfile, 'r') as file:
                    data = json.load(file)
                    get_player_score_fromjson(data)
                    
#                     print(metadata)
personal_comm
# Out:
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1168514
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1168514/innings01
# opening comm_part1.json
# 10.45pm We're all set.
# Let's hope the weather stays clear.
# Mashrafe Mortaza gives his team a pep talk before the huddle disperses.
#
# working with Mashrafe
#
# Mashrafe found
#
# Sunil Ambris and Shai Hope will open West Indies' batting.
#
# working with Sunil
#
#
# working with Ambris Shai Hope
#
# Mashrafe has the new ball, as always.
# Worried glances from the umpires, looking up at the clouds.
# One wide slip in place.
# Vinod Rajpal: "Was awaiting for Shakib's 250th ODI wicket from last 2 ODIs....now have to wait till 2nd of June !!"
#
# working with Vinod
#
#
# working with Rajpal
#
#
# working with Shakib
#
# Shakib found
#
# Khademul Haque: "Can BD break the final jinx?
#
# working with Khademul
#
#
# working with Haque
#
# They should, even without Shakib.
#
# working with Shakib
#
# Shakib found
#
# Even though I would prefer Naeem instead of Mosaddek for the final (because I believe against Windies Shakib's bowling would be missed rather than his batting and Mosaddek is nowhere near him as a bowler) but keeping the World Cup in mind, it is a good decision to play him.
#
# working with Naeem
#
# That means the management is more concerned with the ultimate tournament and not taking the pressure.
# It is a good sign, jinx remains jinx when you think of that!"
# Vanja Patrakar: "Looks like Bangladesh testing their bench.
#
# working with Vanja
#
#
# working with Patrakar
#
# Liton Das and Abu Jayed, their best batsman and their best bowler from last match not in playing XI with their star man Shakib rested.
#
# working with Liton
#
#
# working with Shakib
#
# Shakib found
#
# Testing is great but winning at this stage is more important."
# 10.40am Thanks, Sreshth, and hello, everyone else.
#
# working with Sreshth
#
# The skies look quite gloomy as the teams stand for the anthems.
# 10.38am As the national anthems get underway, it's time to welcome Karthik Krishnaswamy to commentary.
#
# working with Karthik Krishnaswamy
#
# khaled: "i think Bangladesh's main opponent is "the law of average""
#
# Jason Holder: "Very crucial game, got some youngsters who aren't going to the World Cup but nonetheless will be aiming to do well.
#
# working with Bangladesh
#
#
# working with Jason Holder
#
# Cottrell isn't available, so Shannon Gabriel is back."
#
# working with Shannon Gabriel
#
# <
# Meanwhile, Arantxa Sanchez Vicario is in Bengaluru in connection with a 10k run this Sunday.
#
# working with Arantxa Sanchez Vicario Bengaluru
#
# Not too many surprises in whom the former world no.1 picks as her favourites for the French Open
# 10.34pm Will the no-Shakib curse haunt Bangladesh in another tournament final?
# Not only has he now missed three straight ODI finals for Bangladesh, but the Tigers are yet to win an ODI final in four previous attempts.
#
# working with Bangladesh
#
#
# working with Tigers
#
# Can they break that run today?
# Have your say while checking out their other final losses.
# M Venkat Raghav: "So Bangladesh remove their best batsman and best bowler from their previous game"
#
# Nitish: "This is a very important game for Darren Bravo the Windies team as a whole.
#
# working with Venkat Raghav
#
#
# working with Darren Bravo Windies
#
# He hasnt done much to justify his spot in the WC so far..just one 50+ score in 11 innings since his return in Dec 2018.
# He may not have a place in the playing 11 when the likes of Pooran and Russell get back into the team but his performance in this series so far hasnt done the team any favours."
#
# working with Pooran Russell
#
# 10.17am Toss - Bangladesh opt to field, says Mashrafe Mortaza.
#
# working with Mashrafe Mortaza
#
# Mashrafe Mortaza found
#
# But no Shakib, still recovering from a back spasm.
#
# working with Shakib
#
# Shakib found
#
# Rubel, Jayed and Liton not playing as well.
#
# working with Jayed Liton
#
# Bangladesh XI: 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Mushfiqur Rahim (wk), 4 Mohammad Mithun, 5 Mahmudullah, 6, Mossaddek Hussain, 7  Sabbir Rahman, 8 Mohammed Saifuddin, 9 Mehidy Hasan Miraz, 10 Mashrafe Mortaza (capt), 11 Mustafizur Rahman
#
# West Indies XI: 1 Sunil Ambris, 2 Shai Hope (wk), 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Jason Holder (capt), 7 Fabian Allen, 8 Ashley Nurse, 9 Kemar Roach, 10 Ramon Reiffer, 11 Shannon Gabriel
#
# Nitol: "That makes it three consecutive ODI final for Bangladesh without Shakib due to injury"
#
# Sherwin graham: "Goodmornng, I think windies should try something different, take Bangladesh out of their comfort zone, the tigers have beaten windies twice batting second.
#
# working with Soumya Sarkar
#
# Soumya Sarkar found
#
#
# working with Mushfiqur Rahim
#
# Mushfiqur Rahim found
#
#
# working with Mossaddek Hussain
#
#
# working with Sabbir Rahman
#
#
# working with Mohammed Saifuddin
#
#
# working with Mehidy Hasan Miraz
#
# Mehidy Hasan Miraz found
#
#
# working with Mashrafe Mortaza
#
# Mashrafe Mortaza found
#
#
# working with Rahman West
#
#
# working with Shai Hope
#
#
# working with Darren Bravo
#
#
# working with Roston Chase
#
#
# working with Jonathan Carter
#
#
# working with Jason Holder
#
#
# working with Ashley Nurse
#
#
# working with Kemar Roach
#
#
# working with Ramon Reiffer
#
#
# working with Shannon Gabriel Nitol
#
#
# working with Shakib
#
# Shakib found
#
# This is a finals, if windies win toss insert the tigers.
# Bangladesh have not had any pressure, they was bossing around windies in those two games. "
# A. Sensarma: "This is a very paradoxical dilemma, and it will help both teams going forward because similar weather will be seen in England at this World Cup, in similar high-pressure circumstances: do you put runs on the board first to avoid scoreboard pressure (and afflict it on the opposition in the big games), or do you go for stability chasing in the face of interruptive weather instead?
#
# working with England
#
# Considering this is a trial-and-error tournament, irrespective of the result both teams will learn lessons today!"
# Rajiv Jaiswal: "Sakib likely not to play today... Looks like Bangladesh have reserved him for world cup...
#
# working with Rajiv
#
#
# working with Jaiswal
#
# Strategically correct...
# Chances of rain will certainly reduce the total numbers of play today"
#
# 10am Just fifteen minutes to go for the toss, but there's a bit of weather around in Malahide today.
# Cloudy skies, temperatures of 11 degrees, with a fairly high chance of rain in about an hour.
# Win toss, bat second then?
# Mahmudul Haque: "I think toss will tell both teams fortune."
#
# working with Mahmudul
#
#
# working with Haque
#
# Gazi gazi : "Dear cricinfo could you please publish my comment please!!!
# Is mahanadulla and shakib injury serious and any updates in em?"
# -- Hey, we understand that a call on Shakib will be taken today morning.
#
# working with Shakib
#
# Shakib found
#
# Mahmudullah should be fine to play
#
# SAHIL KANWAR: "A match between Bangladesh and West Indies in Ireland.Wondering how the crowd would be .I guess it would be filled with cricket lovers like me.
#
# working with Bangladesh West
#
# :)"
#
# 9.55am We're in Malahide for the final of the Tri-nation series hosted by Ireland.
# Today we have West Indies meeting Bangladesh for their final official ODI before the World Cup, but thoughts of that tournament need to wait.
# Both teams have an opportunity to win a trophy today, and it's the perfect way to simulate big-match moments that teams may face during a World Cup knockout game.
# So expect a high-octane contest.
# West Indies are looking to avoid a third-straight loss at the hands of Bangladesh in the tournament, while the Tigers may be without Shakib Al Hasan today.
#
# working with Shakib Al Hasan
#
# Shakib Al Hasan found
#
# Team news and match preview right here for you to dig in.
# My name is Sreshth Shah, and together with Karthik Krishnaswamy, we welcome you to ESPNcricinfo's coverage of this game.Saifuddin.
#
# working with Sreshth Shah
#
#
# working with Karthik Krishnaswamy
#
# Seth: ""Mashrafe has the new ball, as always."
# I wouldn't say as always.
# :) Just last game he didn't come on until the 29th over!!
# Although that was an anomaly.
# "Third man and fine leg back, one wide slip.
# Same field as Mashrafe, pretty much.A little bit of nibble off the pitch, and the ball isn't quite coming on as well as the batsmen would like, just yet.
#
# working with Mashrafe
#
# Mashrafe found
#
# Tasmeem: "This is the final testing phase, so it was the perfect chance to experiment at a dead rubber.
# Don't think he would do the same at any crunch match.
# Also looks like there will be no place for Liton in the playing XI at the World Cup as well.
#
# working with Liton
#
# "Chris Lawrence: "At who's expense would Chris 'Universe Boss' Gayle and Andre 'The Giant' Russell play at the CWC19?"
#
# working with Chris Lawrence
#
#
# working with Boss
#
#
# working with Gayle Andre
#
# -- Hope and Carter, from this XI?
#
# working with Hope Carter
#
# And I'm also guessing Hetmyer comes in for Chase.
#
# working with Hetmyer
#
#
# working with Chase
#
# opening comm_part5.json
# around the wicketTime for drinks.
# Vinod Rajpal: "Very solid start now from these two openers, Seems a Poor decision by BD to field first in a big match like Finals ; a team should always look to bat first...." -- but the weather?Hope getting some treatment from the physio.s m rashid: "Captain should come and try to breakthrough"Mashur: "@Vinod: Didn't get your point of considering the bowling first decision as a "poor" one.
#
# working with Vinod
#
#
# working with Rajpal
#
#
# working with Seems Poor
#
#
# working with Mashur
#
# Bangladesh won the earlier games by chasing very comfortably & surely they would like to remain in the same run too.
# How do you know the BD top order won't bat better than them?
# In earlier games of this tournament the BD middle order didn't even need to bat as the top orders outplayed the opponents.
# "A few more umbrellas being opened in the stands.
# Drizzling, but play continues.Change of bats for Hope.
# Here's Miraz5.27pm Ahoy, we have live pictures.
# Sunny-ish conditions.
# Five Powerplay overs in the second innings.
# Four bowlers can bowl a maximum of five overs, while one can bowl four overs.
# 5.20pm Ten minutes till play resumes.
# Tasfik Rukan: "When ICC will come to sense to consider for a reserve day for every tournament final?
#
# working with Tasfik
#
#
# working with Rukan
#
# Now we can see that unfair thing happens to both team. "
# -- how does it matter?
# Even if there was a reserve day, play would've happened today itself, considering the ground has dried up.
# And in Malahide, tomorrow is predicted to be a wet day too.
# Suman: "@Hardik - if you look at the first match between WI and BD in this tri-series, WI were posed to run away with the batting, only to be brought back by the BD bowlers in the middle overs / late overs.
# BD is better equipped at the 50 over format and it will be unfortunate for them to take away this option.
# But they need to grit it out and give it their all"
#
# Nasir Uddin: "If today play start again..surely i will miss Liton das badly"
#
# hardik: "To IBM33's point, the batting team almost always scores heavily in the last few overs even after the bowling team has been bowling keeping 50 overs in mind.
#
# working with Nasir Uddin
#
# The DLS system is based on past patterns, which means WI are rightly expected to have scored heavily towards the end even if Bangladesh do their best to stop them.
# Don't think any better solutions have been proposed. "
# 5.15pm Sadman Hasan: "It's like after dominating all through the tournament Bangladesh will finally be faced with a match situation where the odds are heavily stacked against them.
#
# working with Sadman Hasan
#
# They are gonna have to be at their best of forms to turn the tides over here and clinch the title.
# It is going to be a real test of temperament and skill for Bangladesh players."
# Titash: "Imagine if Dre Russ were to come in now!"
#
# working with Imagine Dre Russ
#
# -- *Shudders*
#
# Vivek: "I know Russell is in form of his life, but I still feel he has to prove a lot at international level."
#
# working with Vivek
#
# Mahneel : "Fair point by IBM133, a skipper usually holds back his best bowlers in the middle overs and uses them more in the death.
# If Mashrafe knew the match would be curtailed to 24 overs, surely he would bowl out his bowlers (not that his bowlers were doing particularly well here though)"
#
#
#
#
#
#
#
#
# Neeraj: "Forecast shows more chances of rain, how does it exactly look like right now ?
#
# working with Mashrafe
#
# Mashrafe found
#
# Is the sun out ?"
# -- Gloomy, but dry.
#
# working with Gloomy
#
# And yes, rain is expected all evening.
# I won't be surprised if it drizzles even before the players make their way out for the 5.30pm start.
# IBM133: "If the BATTING team was batting as if they were playing like a 50 over game, then the BOWLING team was also bowling as if they were playing 50 over game and chase the target within 300-32.
# We need a fair DLS rule :)"
#
#
#
# 4.45pm We have news for you, and it's good news.
# Play will resume at 5.30pm, and we'll have a 24-overs-a-side match.
# David: "It's a shame DLS targets are going to ruin this final as a spectacle, means even before they start batting Bangladesh have no chance " -- Better than having no cricket, mate
#
# Kalu: "So the target for BAN will be whatever WI score in 24 overs and not some ridiculous number?"
#
# working with David
#
#
# working with Kalu
#
# -- It will be a somewhat ridiculous number since West Indies were batting as if they were playing 50 overs.
# Will be their disadvantage if the target isn't adjusted
#
# CricFan Naim: "Who will win eventually if there's no play today?"
# -- Bangladesh will be awarded the trophy in that case, since they topped the league table.
#
# working with Bangladesh
#
# 4.33pm Next inspection at 5.15pm, according to the Twitter feed of Windies cricket.
#
# working with Twitter
#
# Karthik's back to give you guys company.
#
# working with Karthik
#
# Faruk: "The match should be called off.
# It's really very dangerous surface for both teams.
# World Cup is knocking at the door.
# As a cricket fan, I want to see all the stars will play for their country. "
# Mahneel: "Chase at a quick rate, tournament final, foreign condition, all of Bangladesh's kryptonite accumulated together. "
#
# working with Bangladesh
#
# Habibur Rahaman: "What will be the target for Banladesh if Windies don't bat anymore and BD are to bat for 20 overs?"
#
# working with Habibur
#
#
# working with Rahaman
#
#
# working with Banladesh
#
# -- If West Indies don't bat again, we hear Bangladesh will need 203 to win in 20 overs.
# But better to wait for the official word.
# Arup: "Will windies bat again or not?"
# -- your guess is as good as mine.
# Mmp Rubel: "It's frustrating to see the match is not starting despite rain going away for a while now.
#
# working with Mmp
#
#
# working with Rubel
#
# Don't think the outcome is important anymore! "
# Dean: "They shouldn't play on a wet outfield and risk injury at any point.
# The World Cup shouldn't even come into the picture.. it's an international game and the players safety should always be put first."
# 4.19pm Further inspection at 4.40pm, which begs the question - with a World Cup approaching should the teams even bother playing on a wet outfield and risk injury?
# 4.05pm Seems like the covers are coming off.
# Mihit: "I would take a Pollard over someone like a Braithwaite/Darren Bravo, any day in my team"
#
# 3.48pm Next inspection at 4.10pm.
#
# working with Pollard
#
#
# working with Bravo
#
# A 20-over shootout is possible as long as the game starts by 6pm.
# Davo: "I hope the game restarts.
# Everyone talking about bangladesh not winning a final, but i'm hoping Windies win because it will be their 1st series win in 5 years...Holder has never won an ODI series since becoming captain in 2014"
#
# Morsel Rafez: "A 20 over game ?
#
# working with Holder
#
#
# working with Morsel Rafez
#
# That means WI wont be able to continue batting.
# And looking at the score I dont think the target for Bangladesh will be more than 170 in 20 overs.
# I think BAN wont mind at all chasing 170 at this ground ( as it was good before the rain)" -- think it will be closer to 200, by the way
#
# Stats Black: "I dont see how Pollard fits in the mix of things.
#
# working with Stats Black
#
#
# working with Pollard
#
# it would make more sense to replace Allen with Chase and Ambris for Bravo/Braitewate."
#
# working with Allen Chase Ambris
#
# 3.35pm It's now three hours and 20 minutes, roughly, since the time the players went off the field.
# And two hours and 23 minutes since we started losing overs.
# Latest from the ground: Rain has paused for the last five minutes and match referee Chris Broad is surveying the ground.
#
# working with Rain
#
#
# working with Chris Broad
#
# Meanwhile, over at Trent Bridge, Babar Azam has just brought up his ninth ODI hundred.
#
# working with Trent Bridge
#
#
# working with Babar Azam
#
# Andy: "Most of the arguments made against Pollard are ill-founded.
#
# working with Andy
#
#
# working with Pollard
#
# Pollard is one of the better rotaters of strike among current West Indian batsmen.
# He is an unbelievably good fielder and will help to lift the standard of our fielding.
# His current batting average is not a true reflection of his ability and it will only get better if he plays more ODI cricket in this batsman-friendly era.
# Conclusion, the man will add value to the side in more ways than one."
# -- We'll soon see whether CWI agrees with you or with Kevin...
#
# 3.15pm Thanks, Sreshth.
#
# working with Kevin
#
#
# working with Sreshth
#
# Nothing to say, really.
# We're all just waiting and hoping.
# Here's the latest from Justin: "They are continuing to work out on the covers, its really frustrating as it really is only little drops of rain.
#
# working with Justin
#
# Just one blotter left in the middle going up and down over the covers."
# Kevin Snaggs: "I'm from Trinidad and agree that Pollard should not be on the WC team.
#
# working with Kevin
#
#
# working with Snaggs
#
#
# working with Pollard WC
#
# His ODI record does not merit a place on the squad.
# I will be even more controversial and question Darren Bravo's place on the side based on his ODI form for the past year.
#
# working with Darren Bravo
#
# Darren has not produced for the WI this year, he has one 1/2 century.
#
# working with Darren
#
# As a top order batsman this is not good enough.
# There is great talent in this current side that one can argue deserve a spot ahead of him. "
# Elsewhere, Lungi Ngidi of South Africa is itching to have a go at India in the World Cup.
#
# working with Lungi Ngidi South Africa
#
# He calls the game a potential 'revenge' contest.
# Yum.
# Speaking of yum, time for a dinner break.
# Karthik's going to take over.
#
# working with Karthik
#
# 2.59pm Oh dear, the rains are back!
# Justin quips, "that's the weather in ireland, looks like it might have passed over, they are still working on the covers."
# Faisal: "What happens if there is no result , will the trophy be shared or bd will get it since they have more points?"
# -- Bangladesh will lift the trophy
#
# Ben Hebbert: "Not only is Pollard's ODI record distinctly average, but he is also another player who eats up a ridiculous number of dot balls.
#
# working with Ben Hebbert
#
#
# working with Pollard
#
# Are people seriously suggesting he should bat No.6?
# Jason Holder is a far superior batsman.
#
# working with Jason
#
#
# working with Holder
#
# Pollard would be an unnecessary selection in the WC squad. "
#
# working with Pollard
#
# Meanwhile, with the NBA Conference finals on, all eyes are on the best in the business.
# Here's a little story decoding the relationships that unleashed the greatness of Steph Curry
# 2.55pm The umpires are in the middle.
#
# working with Steph Curry
#
# Wish we could be a fly on the wall, listening in on their conversation
#
# Anon06: "A few overlooked facts regarding the debate on Pollard's possible selection: The Super50 was played in October (earlier than usual) to allow all "stars" to turn up and stake a claim to WI selection for the the Bangladesh and England ODI series, and from there, the WC.
#
# working with Anon06
#
#
# working with Pollard
#
#
# working with Bangladesh England
#
# Pollard made 69 runs in 7 innings, averaging 9.85 and a SR of 88.
#
# working with Pollard
#
# Top score of 30.
# 5 sixes.
# Is he really worth it?
# Remember he averages under 26 after 101 ODIs.
# Selection for a WC should NOT be based on PSL and IPL performances."
#
# working with Selection
#
# AA Musabbir: "Long delay due to rain.is there any chance of changing pitch behavior due to rain?when will all stadium have roof that weather will not a fact during cricket.weather makes a busy day to a lazy day."
# -- definitely.
# Expect wet balls (the outfield at Malahide is not covered), difficulty for spin bowlers, sluggish batting conditions for an hour or so
#
# 2.40pm We await news.
#
# working with Malahide
#
# Hopefully it's good.
#
# working with Hopefully
#
# Nothing to report yet.
# There will be an inspection at 3pm, we hear.
# Nitish: "@AK: The issue going forward would be the very definition of a "sporting wicket".
# Who is to decide what the par score is ?
# In the age of T20s where the run rate is around 7 and upwards, fans wants and to see more boundaries.
# What we are seeing is the inevitable convergence of the playing styles of ODIs and T20s.
# I dont like it either, but we have to embrace it."
# Nitol: "As far as I can recall, Bangladesh did win a triangular series before!
# Didn't they win the triangular series at west indies played between Bangladesh, Bermuda and Canada in 2007, right before the world cup?
#
# working with Bangladesh
#
#
# working with Bermuda Canada
#
# I am sure that was International one day because Shakib's 134* against Canada is still his career best."
#
# working with Shakib
#
# Shakib found
#
# -- Yes, but it didn't need a final to crown the title.
# It was a league-type tournament.
# Bangladesh have been awful in ODI finals
#
# Capitan Daniel: "I'm not like the best knowing fan of cricket right now but you on cricinfo sure will help me with this: what happened with west indies superstars Pollard, DJ Bravo, Narine, why they don't play for the world cup?"
#
# working with Capitan Daniel
#
#
# working with Pollard
#
# -- Well, they weren't quite in the team's radar under the previous WICB President, but a new President has seen them in the reckoning again.
# Narine, unfortunately, has an injured finger so isn't available for the World Cup.
# DJ Bravo hasn't been considered in the preliminary squad (and has since retired) while Pollard isn't yet in the squad, but we hear murmurs that he may just sneak into the 15 come May 23rd - the final day to announce squads
#
# 2.34pm Our scorer Justin Smyth says that the rain has nearly stopped and the sun is (almost) sneaking out of the clouds.
#
# working with Justin Smyth
#
# The umpires are walking around
#
# AK: "Its pathetic to see batting paradise all around UK now a days.
# Some nation are making this ODI a format for batsman only.
# Team scoring 350 and then thats being chased down with 6-7 over spare.
# Utterly ridiculous!!!
# ODI should be done on sporting pitch where reward for good batsman and bowler will be there only.
# This kind of pathetic pitch will make some mediocre batsman to the same bracket as the legend like Sangakara. "
# Jack: "Perfect song for the current circumstance Srethth!
#
# working with Srethth
#
# As well, I played only a minute of the WC theme and its pretty dull..." -- I think the 2019 song will grow on us as the WC approaches.
# As for favourite WC theme songs, this one was pretty nice.
# Anon06: "I like the rhythm of the WC song but dislike it for several reasons: Gives off a football vibe rather than cricket, can't understand what is being said, and I feel WC songs should reflect the region where the WC is being played.
# This song does not.
# Best by far has been Game of Love and Unity in 07.
# Just my (un)biased analysis."
# -- the song is meant to celebrate England's cultural diversity, so I guess it ticks that box
#
# 2.22pm Eyy, KK - that's some pressure.
# Hello again guys.
# Akash592: "As a West Indian, I'm really not feeling that WC theme song man!"
# -- I'd rather have this as the theme song man
#
# 2.20pm No real change in conditions, as far as I can tell.
# Let's see if Sreshth can appease the cricketing gods a little.
#
# working with Sreshth
#
# Mofrad: "Curious to know the expected playing 11 of Windies during the world cup.
# 1.
# Gayle 2.
# Hope....and then?"
# -- I'm guessing they were initially going with something like Gayle, Lewis, Hope, Hetmyer, Darren Bravo, Russell, Holder, Nurse, Roach, Gabriel, Cottrell, with Allen coming in for one of the quicks depending on conditions.
#
# working with Gayle
#
#
# working with Lewis
#
#
# working with Hetmyer
#
#
# working with Darren Bravo
#
#
# working with Nurse
#
#
# working with Roach
#
#
# working with Gabriel
#
#
# working with Allen
#
# Let's see what their final squad is, now that the likes of Ambris and Campbell have put their hand up.
#
# working with Ambris Campbell
#
# Abhijato: "The World Cup theme song premiered globally just a few minutes ago.
# Your thoughts about it?"
# -- Just heard it.
# It's a nice song, but it doesn't give me proper World Cup feelz, you know what I mean?
# I like the video more than the song.
# And in case you haven't heard it yet, here it is:
#
#
#
# Shuvayan: "203 seriously?
#
# working with Shuvayan
#
# Even Windies won't going to score 200 in 30th over.
# Ridiculous DL method to follow."
# -- Well, West Indies began their innings thinking they would need to bat 50 overs, which would obviously demand a very different approach than if they were going in with 10 wickets in hand and only 20 overs to play out.
# 2.00pm Another update from Mr Smyth.
# Mushfiq: "If the game reduces to 20 overs, then what will be target for Bangladesh?"
#
# working with Bangladesh
#
# -- Great question.
# By our calculations, it's 203.
# Abhinav Potadey: "I have a serious question here.. why can't they cover the whole ground instead of only covering the pitch area.I saw that in Eden gardens.
#
# working with Abhinav
#
#
# working with Potadey
#
# Also Ireland now being a Test nation should think about it so that Irish crowd can view more cricket at their home turf.
# I see out of every three games,one game gets washed out due to rain in Ireland..bad tactics from Ireland Cricket" --- Yeah, it's puzzling.
# Outside of India and Sri Lanka, most grounds seem to only cover the square and the bowlers' run-ups.
# 1.45pm CWI's emoji-in-picture game is pretty damn strong.
# Update from Justin at the ground: We're in for a bit of a wait even if it stops drizzling soon.
# "You'll probably find that they won't look to improve the drainage here at Malahide because they are going to develop the ground at Abbottstown instead.
# So many hours ahead watching the ground dry."
# 1.35pm Thanks, Sreshth.
#
# working with Sreshth
#
# Not much to say right now.
# The covers remain on at Malahide, and there's no activity at the ground while the DJ shuffles through their tunes.
# We don't know if you'll want to read Shahid Afridi's autobiography, but you do not want to miss Osman Samiuddin's review.
#
# working with Shahid Afridi
#
#
# working with Osman Samiuddin
#
# Jalal: "I think Bangladesh need to actually play and win this match to truly exorcise their demons otherwise this trophy win will just be a footnote.
# Cricket authors will use parentheses to clarify how this trophy win came about and the memories of an experience of winning a knockout match would not implant themselves into the minds of our players."
# Jack: "11 degrees, cloudy and rain, can't think of anything more depressing...."
#
# Shibly: "Welcome Karthik.
# Hope your arrival will make some changes in luck."
# -- Let's hope so!
# Vinod Rajpal: "Shamya came in for comms for 55 minutes....then Sreshth joined for 35 minutes ; KK relieving Shah within 25 minutes !!
#
# working with Vinod
#
#
# working with Rajpal
#
#
# working with Shamya
#
#
# working with Sreshth
#
#
# working with Shah
#
# what is the weather update ??"
# -- Same as it has been for the last 55 + 35 + 2 minutes, more or less.
# 1.33pm Time for a change in commentary.
# Here's Karthik Krishnaswamy.
#
# working with Karthik Krishnaswamy
#
# 1.26pm Still no change in conditions at Malahide.
# A reminder, We began losing overs from 1.12pm.
# Bangladesh will lift the trophy if today's a washout.
# TQ: "Worth mentioning that 2 years ago, Ireland had a tri nation series with Bangladesh and New Zealand.
# Bangladesh would have won the series if their first match against Ireland hadn't washed out.
# They beat new zealand in the final game of the series and unfortunately at that time, there were no finals, only team who finished top of table would be the winner"
#
# Anon06: "Has Ambris convinced anyone yet that he should replace Lewis at the top?
# working with Has Ambris
#
#
# working with Lewis
#
# In-form players should get the nod above reputation (not that Lewis' reputation in ODIs is great).
#
# working with Lewis
#
# This is a WC where performances are required from Game 1."
# -- well, Ambris has done whatever he could with the little opportunity on offer.
#
# working with Ambris
#
# Lewis is a match-winner on his day, not sure if Ambris has been able to prove himself in that manner just yet
#
# Ataur Rahman: "@Dean, It's because of recent history of BD, we lost several finals .
#
# working with Lewis
#
#
# working with Ataur Rahman
#
# BD fans will be very much happy to see this jinx break.
# Even if its a mini tournament with weak teams.
# Afterall, world cup is ahead."
# Shajib Al Hasa: "Really agreed to you #Seazon ... because we are the Real Tigers we love to play like Tigers ..
#
# working with Shajib Al Hasa
#
# Even if we will get 350 target we still believe our Tigers will chase it like Fearless Batting <3 right ?? "
# -- love the fandom, Shajib.
#
# working with Shajib
#
# Rakib: "I don't think outfield and drainage system of Malahide is as good as Mirpur.
#
# working with Malahide
#
# Even Mirpur, with its fantastic drainage system, would struggle to resume the game after rain in such cold and overcast condition."
#
# working with Mirpur
#
# Sadman: "@Dean u r forgetting Bangladesh won back to back series against full strength West Indies team last year. "
#
# working with Sadman
#
#
# working with Bangladesh
#
# 1.12pm We begin to lose overs now.
# But there's good news for fans of cricket - the rain is slowly coming to a close, and the skies are getting brighter.
# No sun, but definitely not as dark
#
# Arup: "@davo no one had siad WI can't win today.
# We all want 100 over game and it will decide the winner. "
# Dean: "Why is everyone making out this will be massive for Bangladesh to win this mini tournament?
# They've played against a depleted WI side and Ireland!! "
# Seazon: "Really don't want a throphy because of rain.
# It will be our first multinational trophy, but winning in such a way will hurt always.
# There won't be any stories for our grandchildren!! "
# Davo: "So because Ban has beaten Windies twice it means they will win today?
# Are you guys following football or cricket??
# Windies are well placed here and it will only benefit them even further if this match is reduced, they have all 10 wkts so DLS target will be greatly appreciated. "
# Araf: "Bangladesh wants to win the trophy by playing.
#
# working with Araf
#
# We Bangladeshis don't need the help of rain. "
# Vinod Rajpal: "300 seconds for loosing one over ; How will they calculate Ravindra Jadeja's Over as he only takes 120 seconds for his over !!"
#
# working with Vinod
#
#
# working with Rajpal
#
#
# working with Ravindra Jadeja
#
# 1.08pm Confirmed: We will start losing overs from 1.12pm.
# We will lose one over for every 4.50 minutes.
# And here's Sreshth back again.
#
# working with Sreshth
#
# Scott: "What's the answer to Q1??
# This rain massively benefits Bangladesh " -- not sure whether Bangladesh would want to lift the trophy that way.
# They've beaten WI twice already and no reason why they can't win the match in itself
#
# Abdullah: "As much as I want Bangladesh to win the tournament by winning today, I'll take the washout.
#
# working with Abdullah
#
# Bangladeh really needs this.
# They've come so close so many times.
# Don't want it risking again.
# Come on rain. "
# While we wait for an update, here's an interesting one - the all-time World Cup XI as chosen by you
#
# Answer to Q2: Cricket Ireland has confirmed that Bangladesh will lift the trophy in case of a no-result today.
#
# working with Answer Q2
#
#
# working with Cricket Ireland
#
# Better results in the group stage.
# If it happens, it will be Bangladesh's first win in the final of a multi-team ODI tournament.
#
# working with Bangladesh
#
# Answer to Q3: Nope; as such, this is the forecast for tomorrow: Mostly cloudy, showers around.
#
# working with Answer Q3
#
#
# working with Nope
#
# Questions
# 1.
# When do we start losing overs?
# 2. Who wins if we don't get a result today?
# 3.
# Do we have a reserve day?
# - We're checking on these and will get back to you soonest
#
# 12.45pm Justin Smyth's update from Malahide is: "The rain is slowing down, so I'm hopeful that there will be more play.
#
# working with Justin Smyth
#
# But it's just so cold, so there is no sun to help dry the ground."
# It doesn't look good at all, unfortunately
#
#
#
# Jack: "Whilst be have you Shamya, who is your pick for WC glory??"
#
# working with Whilst Shamya
#
# - Dunno, but they'll go back home with a lot of money
# 12.35pm Here's the latest weather update
#
#
#
# For people asking about Mahmudullah, here's Isam's update: "He is on the mend, he is still a few weeks away from being cleared to bowl."
#
# working with Mahmudullah
#
# Mahmudullah found
#
#
# working with Isam
#
# Likely he will play as a batsman-only at the World Cup to start with.
# Mikhail: "Ambris is currently averaging 102 and can't make the world cup squad that's a bit tough" - it is, isn't it?
#
# working with Mikhail
#
#
# working with Ambris
#
# And that squad (which can change, of course) has Gayle and Lewis too.
#
# working with Gayle Lewis
#
# Paul Muchmore: "Hi Shamya!
#
# working with Paul
#
# Cricinfo ball by ball debut?"
# - more like subbing for Sreshth while he takes a break for the rain.
#
# working with Sreshth
#
# "Mahmudullah has a problem in shoulder.
# That's why Mosaddek came into the squad.
# Mahmudullah won't bowl in the world cup either," says Farhan - messes with the team balance, doesn't it, if Mahmudullah doesn't bowl at all?
#
# working with Farhan
#
#
# working with Mahmudullah
#
# Mahmudullah found
#
# 12.25pm This might not mean a terribly long delay, just a passing shower hopefully.
# But we'll know only when we know.
# 12.13pm And we're going off, folks.
# Rain getting heavier, and the covers are coming on.
# The players have hared off already.
# Time for Shamya Dasgupta to have a crack on commentary.
#
# working with Shamya Dasgupta
#
# Remember to tell him hi!
# Underachiever: "Seems like Masrafe does not rate Mahmudullah's tweaks.
#
# working with Masrafe
#
#
# working with Mahmudullah
#
# Mahmudullah found
#
# Surprising given he is usually tight and has the knack of breaking partnerships.
# Wonderful batting by Hope and Ambris."
#
# working with Hope Ambris
#
# Mashur: "Oh!
# No rain no!
# Don't spoil the taste of watching Bangladesh chasing a 350+ score.
# Please stop asap!"
# Adam: "Is that Campbell guy injured or something?
#
# working with Adam
#
#
# working with Campbell
#
# 150 in the first match and he didn't get another chance.
# seems harsh" -- yes.
# Some back trouble5.30pm Miraz, around the wicket
#
# working with Miraz
#
# opening comm_part3.json
# No bowling changes yet.
# Saifuddin continues.Arzoo : "This is very good and sensible batting from WI, even though both bowlers are consistently bowling good and tight lengths still they are rotating strikes by singles and odd boundaries when available!
# Contrary to Tiger batters who waits for boundary balls instead of rotating strikes and hence creates self pressure!"
# -- You're underrating Bangladesh's batting there!
#
# working with Bangladesh
#
# Mashur: "Bangladesh is bowling very tightly since the last Asia Cup.
# They badly need to continue this run to acheive something big in the World Cup"First bowling change, here's Mustafizur Rahman from left-arm over.
# A wide gully in place.Mid-off drops back to long-off, not sure who's moved inSpin for the first time, here's Mosaddek Hossain.
# Anwar: "Out of 11 players in Bangladesh team, eight of them has name starts with the letter "M"."
# opening comm_part2.json
# Fine leg's come in for square leg to drop back, at the start of this over.PrashantBanjare: "If Windies wants to win today then they have to dominate spinners but with some sense.
# They should try to use their feet and compel them to change their length can't allow them to just bowl and eating the overs without any runs being scored. "
# -- Good point.
# They let Mehidy and Shakib, in particular, to bowl where they wanted.
#
# working with Mehidy Shakib
#
# opening comm_part4.json
# Spin from both ends.
# Here's Mehidy.Bimal Sinha: "Hope is the Kohli of WI.
#
# working with Hope Kohli WI
#
# Consistency at its best!
# "Another bowling change.
# More spin, here's Sabbir to bowl some legbreaks.
# opening comm_part6.json
# NK: "BD fans ..calm down ...Bangladesh batting is capable of take down 220 target in 24 overs.."Pradeep: "A winner is one who braves all odds come what may, so all dear BD fans life is not fair but whoever swims across the tide is always remembered.
# Try hard in the conditions accorded to you and you will definitely see your team remembered.
# "Badal Chandra M: "Is all the comments are read by cricinfo?
#
# working with Badal Chandra
#
# or some of them are chosen arbitrarily?
# @suman made the same point as mine and his comment was published.
# ain't jealous but just curious."
# --- well, what do you think?
# :) Also, only a 10-minute break between inningsSuvo: "To the Bangladeshi fans: I guess this is a blessing in disguise.
# First time Bangladeshi batsmen are facing a real challenge to chase down a massive total, surely a much needed pre-wold cup practice.
# "Free hitVinod Rajpal: "@BD fans ; Deciding to field first was their call - so they would be prepared for the target !!
# "Neeraj: "I think WI will look to save wickets here, as it will boost the target after DLS comes into application."
# -- yep, looks like the planHere's BravoOne over to go.
# Can West Indies breach 150?
# Remember, Bangladesh will have to chase way more than 150 courtesy DLS.Ik: "When the going gets tough, the toughs get going.
#
# working with Bangladesh
#
# "rahat: "I'm going to sleep.
# There's nothing left for BD in this match.
# But I'm really proud how they performed in the series.
# Congrats to WI for winning the trophy " -- stay!
# They may just surprise youfinal ball of the innings.5.45pm So, that's the end of West Indies' innings.
# A terrific first-wicket stand - which happened more than three hours ago - ensures Bangladesh need 210 to win in 24 overs.
# Hope and Ambris finish their tournament on a bright note.
#
# working with Hope
#
#
# working with Ambris
#
# Can their bowlers now deliver?
# We'll be back in 10 minutes to learn more.
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1168514/innings02
# opening comm_part1.json
# 5.53pm We're all set for the chase.
# Tamim Iqbal and Soumya Sarkar are striding out to begin Bangladesh's chase.
#
# working with Tamim
#
# Tamim found
#
#
# working with Iqbal Soumya Sarkar
#
#
# working with Bangladesh
#
# West Indies will start with spin.
# Ashley Nurse from round the wicket, with two left-handers at the crease.
#
# working with Ashley
#
# A slip in place.No slip now.
# A short extra-cover is in place instead, plugging the big gap that the ball just went through.Jason Holder from over the wicket.
# A wide slip in place.
# So the three Powerplays will be overs 1-5 with two on the rope, then 6-19 with four men out on the boundary, and 20-24 with five on the boundary.Kemar Roach now, from right-arm round.
#
# working with Roach
#
# A wide slip in place for him too.Over the wicket now.Can Shannon Gabriel slow down Bangladesh and Soumya?
#
# working with Shannon Gabriel
#
#
# working with Bangladesh Soumya
#
# Over the wicket.Davo: "Since the start of the WI-Eng ODI series i think Nurse has put down about 50 catches, with 49 being straightforward!"
#
# working with Nurse
#
# opening comm_part5.json
# Shihab: "Has any lbw appeal been turned down this inning?"
# -- ha haThings getting cloudy.
# The sky as well as Bangladesh's inningsRashid : "@Shihab, well said, but all were given by Richard Kettleborough who is well reputed umpire.
#
# working with Bangladesh
#
#
# working with Shihab
#
#
# working with Richard Kettleborough
#
# First one was down leg and other two were well judged.
# "The captain's herekhan: "BD equalled WI 152/1 of 24 overs within 17 overs.
# And they are behind the game, this is called luck.
# "Aadil: "Considering their form this tournament, Bangladesh deserves to win the trophy, go Bangladesh go"Richie: "A man who took a wicket to give himself a bowling average of 168 could be the key to Windies winning this.
#
# working with Richie
#
# Crazy!! "
# opening comm_part3.json
# Carl: "I am so afraid for the WI with this bowling attack at CWC 19."
# Roach returns.Raymon Reifer comes on now.
#
# working with Reifer
#
# Left-arm over to Soumya.Left-arm round to Mushfiqur.And with that, it's over to Sreshth for the rest of this chase.
# Bye!Danke, Karthik.
#
# working with Danke
#
#
# working with Karthik
#
# Bangladesh need 116 off 84Hridoy: "Team Bangladesh are getting mature every new morning.
# If they continue to play this way then they will be team to defeat in every format.
# Specially ODI.
# Such a balanced ODI side.
# "NK: "@sreshth..was sabbir's one a out?"
# -- ball stayed low.
# Looked out to me!Jobaer: "@Hridoy, perhaps you are a bit too enthusiastic BD fan.
#
# working with Hridoy
#
# Yes, Bangladesh is improving and showing maturity, especially in the ODI format but they are definitely not THE team to beat.
# ----A BD fan from Memphis, Tennessee"
#
# working with Tennessee
#
# opening comm_part2.json
# Last over of the first Powerplay.
# Holder returns.The difference between this match and T20 will be the next 14 overs, with only four men allowed on the boundary.Sabbir Rahman is in at No.
#
# working with Rahman No
#
# 3.
# Asif: "This is the kind of Soumya we were waiting to see for years.
#
# working with Soumya
#
# Soumya found
#
# Finally coming into a gem of a form in the most crucial time.
# "In walks Mushfiqur Rahim.Vernon: "A message to all the Bangladesh fans.
#
# working with Mushfiqur
#
# Mushfiqur found
#
# I am a West Indian and I want Bangladesh to win this match and win it handsomely to.
# They deserve to win after thrashing West Indies in the previous two matches in this series.
# Also, West Indies bowling and fielding has been substandard and as a result they do not deserve to win here.
# Best of luck!"
# Shahidul Islam: "@Asif, this is why I believe the selectors have him so many chances to Soumya, and I think he is worth it.
#
# working with Shahidul
#
#
# working with Islam
#
# He is the one match winner player for Bangladesh.
# And he and player like Liton das could be leading next generation Bangladesh team.
# "Soumya's on 49 now.
#
# working with Soumya
#
# Soumya found
#
# opening comm_part4.json
# Halfway stage of the innings.
# Bangladesh need less than half the runs.Bid: "Reifer has won the final for his team!"
# -- These two have other ideas, it seemsShahid: "Two nearly bad lbw decision from umpire !!!!"
# -- Tight calls, both.
#
# working with Tight
#
# Looked out to me, to be honest.
# Would've clipped leg even if there was a reviewMinhaz: "I am biting finger now, nail is all gone"Abhijato: "Danyal Rasool just made his BBB debut on the ENG v PAK match, and he's done a fantastic job so far.
#
# working with Danyal Rasool
#
# Do you remember the match in which you made your debut?"
# -- Hey!
# India v Bangladesh, 2017 Champions Trophy Warm-up gameAhsan: "My heartbeat is moving very fast... Now BD players need to calm down and play regular cricket..."
#
# working with Bangladesh
#
# opening comm_part6.json
# Alright then.
# We're in the business end of this game.
# Bangladesh need 39 off four overs.Aranya: "What you meant to say was "We're in the endgame now".
# "Joynul : "20.2, 'SHOT' of the tournament.
# "tadj: "that was some ordinary and defensive minded captaincy from holder, u hadda search for the wicket even if its a 12 run over should have gone gabriel "Bangladesh need 27 off 18.
# If this was a T20 game, you'd back them.
#
# working with T20
#
# Right?
# Riiiight?Fastest ODI fifty for Bangladesh from Mosaddek7.46pm That's all from us at ESPNcricinfo.
#
# working with Fastest ODI
#
# Hope you enjoyed our coverage of this historic Bangladesh win.
#
# working with Hope
#
# A lot for Jason Holder and West Indies to worry out.
#
# working with Jason Holder West
#
# Keep an eye out on our website tomorrow morning, because West Indies are supposed to release their final World Cup squad then.
# Till then, it's goodbye.
# Azweer: "@Tamim Sarker: so it's gonna be a double dhamaka in Dhaka"
#
# 7.41pm Smiles in the Bangladesh camp.
#
# working with Tamim Sarker
#
#
# working with Dhaka
#
#
# working with Smiles Bangladesh
#
# Mortaza hugs coach Rhodes after giving a mighty cuddle to Soumya Sarkar
#
# Shishir : "Finally first multinational tournament trophy!!
#
# working with Rhodes
#
#
# working with Soumya Sarkar Shishir
#
# Congratulations Bangla Tigers!!
# From Nepal!!"
# Aj : "For the love of God Keemo Paul in for Roach please "
#
# Shuvashish Roy: "We have never seen such well-poised and synchronised Bangladesh cricket team before.
#
# working with Paul Roach
#
#
# working with Shuvashish Roy
#
# This would be our World Cup.
# #ShabashBangladesh"
#
# Azweer: "So tomorrow will be a national holiday in Bangladesh....!!!"
#
# working with Bangladesh
#
# Noise.of.silenc: "-What do we say to the GOD of cricket???
# -NOT TODAY!
# ;)"
#
# Tamim Sarker: "@Azweer- Its already national holiday for us tomorrow!
#
# working with Tamim Sarker
#
# Buddha Purnima"
#
# Hridoy: "Mosaddek was 7 from 9 ball.
#
# working with Buddha
#
# And reached fifty in 20th ball.
# This is some hitting."
# Dr. Engr.
# Md.
# M: "Congratulations Bangladesh Cricket Team for the wonderful victory.
#
# working with Bangladesh Cricket Team
#
# Worth to see the match without sleeping."
# 7.40pm Terrific scenes in the Bangladesh camp.
# They've won with seven balls to spare.
# It wasn't easy, with Shakib unavailable, but they were terrific in the last four overs of West Indies' innings after which their batsmen kept the tempo going through the innings.
#
# working with Shakib
#
# Shakib found
#
# First, it was Soumya Sarkar, who struck a half-century in 27 balls.
#
# working with Soumya Sarkar
#
# Soumya Sarkar found
#
# Mushfiqur Rahim chipped in too, but when it mattered, Mosaddek Hossain stood up to take his team through.
#
# working with Mushfiqur
#
# Mushfiqur found
#
#
# working with Rahim
#
# Rahim found
#
# ador: "Wonderful batting display, wonderful Soumya, wonderful Mosaddek! "
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1153252
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1153252/innings01
# opening comm_part1.json
# Liton Das to take first strike, with Nazmul Hossain at the other end.
#
# working with Liton
#
#
# working with Nazmul Hossain
#
# Aftab Alam has the ball.
#
# working with Aftab
#
# One slip.
# 3.28pm National anthems done.
# Bangladesh's openers walking out Afghanistan's huddle done.
# This will be the first time in this Asia Cup that they're bowling first.
# How will they go?
# Nafis: "@Md.
# Ebrahim Mehidy Hasan came from the under-19's too and flourished in intl.
#
# working with Ebrahim
#
#
# working with Mehidy Hasan
#
# cricket.
# However, Nazmul Hossain seems to be very under developed.
#
# working with Nazmul Hossain
#
# He needs to play more domestic cricket along with playing in the A team rather than just being in the intl.
# squad.
# "saikot: "All on a sudden people are going crazy to include Soumya and Imrul in the team.
#
# working with Soumya Imrul
#
# Here is a humble question.
# What so revolutionary they did in regard of their technique in this very short time after they got sacked from the team?
# Not much I guess.
# Both BD selectors and fans are incredibly impatient"Inteser: "Is Imrul Kayes going to open or is he going to slot in the middle order?
#
# working with Imrul Kayes
#
# If he opens, where will Shanto bat, at 3 or down the order?"
# --- I think it's fair to say that if the selectors don't know, then neither do I...Aayan Bashar: "I think they should've brought Soumya instead of Liton.
#
# working with Aayan Bashar
#
#
# working with Soumya
#
# Soumya found
#
#
# working with Liton
#
# Soumya is extremely lethal in form.
# Bangladesh needs to play him matches to get him back into form.
# Remember the old Soumya and Bangladesh opening.
#
# working with Soumya Bangladesh
#
# The invincible duos!
# ...
# opening comm_part7.json
# Richard A: "I hope CDG's Robert Kennedy impersonation doesn't last.
# working with Richard
#
#
# working with Robert Kennedy
#
# He used to bowl single overs that were the length of a decent spell.
# He bowled so many wides, he used to have to stay on the field during the lunch break just to finish his overs."
# --- That's 46-year-old ex NZ cricketer Robert Kennedy he's referring toRoney: "One thing i remember about Robert Kennedy, he wasn't express bowler, but in a match in 1996 world cup, he broke the middle stump once.
#
# working with Robert Kennedy
#
#
# working with Robert Kennedy
#
# Probably against the Dutch, the stump was flying in pieces.
# "Naim Noor Arnob: "Bangladesh should start looking past Mahmudullah.
#
# working with Naim Noor Arnob
#
# He hasn't delivered for a long time for Bangladesh, plus he had a pretty average BPL. "
#
# working with Bangladesh
#
# opening comm_part11.json
# Even though Mehidy is on 16 off 18, Isam believes Saifuddin should bat above himMehidy's shot selection proves why Isam wanted Saifuddin batting above MehidyFerguson comes backOne slip in placeAround the wicket to Saifuddin
#
# working with Isam
#
#
# working with Saifuddin
#
# Saifuddin found
#
#
# working with Isam
#
# opening comm_part9.json
# Andy: "NZ seem to have a recurring theme - knock the top off, but struggle with the middle order.
#
# working with Andy
#
# Boult and Southee will open in the WC, but the change bowlers really need to support them better"Jed: "Southee?
#
# working with Boult
#
#
# working with Southee
#
# He won't be opening for New Zealand at the World Cup Henry or bracewell seems more likely "
# opening comm_part13.json
# Matt Henry for his last overNeesham will bowl the last, Mashrafe will faceMid-on goes deep2.58pm So another below-par total and unimpressive display from the Bangladesh batting line-up.
#
# working with Matt
#
#
# working with Henry
#
# Their approach and shot selection looked slightly better today, Tamim was more watchful early on; they tried seeing through the opening spells but the swinging ball and some accurate bowling from the quicks troubled Bangladesh again.
#
# working with Tamim
#
# Tamim found
#
# Bangladesh were lucky the hosts put down four catches - not even one of them very difficult - and missed a run-out chance or two to cross 200 again this time.
# Mohammad Mithun came to the rescue yet again but the batsmen before him will have to take more responsibility going forward, especially in Shakib's absence.
#
# working with Mohammad
#
# Mohammad found
#
# Mohammad found
#
#
# working with Mithun
#
# Mithun found
#
#
# working with Shakib
#
# Shakib found
#
# Todd Astle, who came in for Mitchell Santner today, also showed his handy legbreaks, and the occasional flipper that dismissed Mithun.
#
# working with Todd
#
#
# working with Mithun
#
# Mithun found
#
# So another modest total to chase, we'll be back in 14 minutes to start that.
# Dave: "Henry has been impressive at the top, but for me he still doesn't have the variation to bowl the death overs.
#
# working with Henry
#
# It hasn't hurt us this series because Bdesh have been down to the tail so early, but I do think we maybe still need Southee."
#
# working with Bdesh
#
#
# working with Southee
#
# opening comm_part3.json
# A leg gully in placeColin de Grandhomme warming up a bit16 runs from the last two oversBoult continues with a leg gullyJay : "Tuning in from the USA.
# I personally think that the way the New Zealand bowlers have threatened the Bangaldesh batsman with accuracy, pace, and swing, shows why they are some of the best fast bowling attacks in the world.
# If Bangladesh want to better in alien conditions, especially in the World Cup, they should work very hard on their batting technique against the moving ball.
# What do you think, Vishal?"
#
# working with Vishal
#
# That's true, although the pitches in England might be drier than this.
# Still, no harm in getting better against the fast and swing bowlersFirst change of the morning - here's Colin de Grandhomme with one wide slip
#
# working with Colin
#
# opening comm_part2.json
# sarat: "Unlike in T20Is, In ODIs u have to respect bowlers and the pitch atleast for 5-6 overs"11.18am And the rain has become heavier, the players are going off and the covers are coming on.
# It's not too heavy, so only the pitch has been covered and it's almost stopped now in fact.
# The umpires are walking on the field with their hands in the pockets, no need for umbrellas yet11.29am The umpires are walking out now, followed by the New Zealand players and the two left-handers from Bangladesh.
# Those batsmen have a tough task ahead in these overcast conditions, Boult is making the ball swing around as usual.
#
# working with Boult
#
# Henry to continue...
#
# 11.25am Good news - the covers are coming off quickly.
# It's still pretty overcast and chilly, little windy at times.
# Naim Noor Arnob: "An absolute nothing shot from Liton.
#
# working with Naim
#
# He must be dropped for a seamer who can bring goods under these conditions."
# They need some batting depth too in these conditionsMatt Henry has been bowling under 140kmh, and a bit short of length unlike Boult who has looked much better todayIn his 200th ODI, here's Mushfiqur Rahim
#
# working with Boult
#
# opening comm_part4.json
# Five deliveries bowled so far in the over, only two counted, three runs and a wicket.
# Here's Mohammad Mithun and two slips for him.
#
# working with Mohammad Mithun
#
# Mohammad Mithun found
#
# They're so close they could hold handsWhat an eventful over that - 11 balls, a wicket, five wides and a four.
# Phew!Lockie Ferguson with his express pace now and a slip
#
# working with Lockie Ferguson
#
# opening comm_part6.json
# Leg gully comes in after thatSimon: "19 extras through 19 overs.
# I've never seen such indiscipline.
# Good teams will punish us at the world cup if we keep this up"John Strachan: "What's the record for most wides bowled in an ODI spell?
#
# working with John Strachan
#
# Colin must be getting close!"
# --- I believe Malinga once bowled 10 wides against Pakistan in 2009, some of which went to the boundary - so a total of 26 runs in wides from his spell that day!
#
# working with Malinga
#
# opening comm_part10.json
# DW: "Henry's looked mighty impressive the last two ODIs.
#
# working with Henry
#
# Surely a lock in for the world cup.
# "rowan findley: "Is there a collective noun for a group of umpires?
# i think it should be a "Decision of umpires".
# "Varun has taken a break for now.
# Astle continuesAstle's last over.
# Can he take one more?Astle completes his fine spell of 10 with 2 for 52, got the wicket of MithunSajed: "Very interesting recovery by Bangladesh.
# It is impressive to see Sabbir's return to be key, and the youngster Miraz working his way up."
#
# working with Sabbir
#
# opening comm_part12.json
# Mashrafe at No.
#
# working with Mashrafe
#
# Mashrafe found
#
# 10, takes a bit of time to collect his helmet and walk outBoult is back, two left for himThirty balls to go, wonder if Bangladesh will bat to the last over today like in the first ODI.
# No Mithun today thoughMustafizur the last man, a slip in place for himShort fine leg in place
# opening comm_part8.json
# Sajed : "@Naim Noor Ahmed The thing is that Mahmadullah is a key player.
#
# working with Naim Noor
#
# During the previous international series, he has been a key part in changing the dynamics of the game.
# Bangladesh needs to practice playing overseas more, and Ireland is a great way for World Cup practice (England would be ideal)"Out comes the physio to have a look at Mithun.
#
# working with Mithun
#
# Mithun found
#
# On his feet now.Ayush Kapoor: "Mithun has showed great composure in both of his inning.
#
# working with Mithun
#
# Mithun found
#
# Hopefully this cramp doesn't affect his innings."
# moving to /mnt/9439c024-e4c1-4178-81f7-44a8e3f2c862/links (git)/commentary-analysis/commentaries/1153845/innings02
# opening comm_part1.json
# 3.14pm The Bangladesh players disperse from the huddle after some talk from Mashrafe, and the New Zealand openers stretch their arms while walking out.
#
# working with Mashrafe
#
# Mashrafe found
#
# Mashrafe will open the bowling again, Guptill will take strike with one slip in place.
#
# working with Guptill
#
# Can Bangladesh make a match out of this?
# Let's see...Varun Shetty will take over nowThanks VishalRichard Mutch: "Just tuning in now.
#
# working with Varun Shetty
#
# Was there an injury or rain delay?
# Did NZ just take 4 hours to bowl their 50 overs?
#
# working with Did
#
# Perhaps the strict guidelines on getting thru your 20 overs quickly in the T20's are contributing to teams (worldwide) taking a more relaxed approach to overates in in tests and ODI's?"
#
# working with T20
#
# --- There was a rain relay in the middle and an injury break too.Readers from the US can watch the 2nd ODI LIVE here, on ESPN+Mashrafe around the wicketKieran: "Little disappointed that NZ chose to bowl first.
# Smart choice for this game, maybe not so much for the World Cup preparation, with games running out.
# NZ really needs to test the batting at putting on a big score, at pace (especially top order).
# between 250 to 300 scoring rate won't cut it against the best teams.
# If BDesh win toss and bats first in the last game we have missed our chance to test the batting unless BDesh manage a really big score."
# opening comm_part5.json
# And a chance in commentary along with the bowling.
# Vishal and Sabbir are in.Thanks, Varun.
#
# working with Vishal
#
#
# working with Varun
#
# Sabbir's presence might make a difference compared to mineAnother change - Soumya Sarkar comes on now, no slips23 off the last two overs even though the Powerplay is over.
# working with Soumya Sarkar
#
# Soumya Sarkar found
#
#
# working with Powerplay
#
# Bangladesh running out of optionsMehidy returnsAnother change - here's Mahmudullah
# opening comm_part7.json
# Guptill's last nine innings: hundred, six scores below 20, and then two hundreds.
#
# working with Guptill
#
# He couldn't score much against India but has collected hundreds before and after that seriesMustafizur's chance to returnImam : "None of the bowlers look like they can force a wicket here.
# "Now Mahmudullah
#
# Nitish: "Have to say that the "Nicholls as a back-up opener for the WC" experiment is starting to lose shape.
#
# working with Mahmudullah Nitish
#
#
# working with Nicholls
#
# NZ desperately need Munro to get back to form or simply hope that Nicholls comes good when it matter."
#
# working with Munro
#
#
# working with Nicholls
#
# Nicholls did get a fifty in the last match but couldn't score much against India, I agreeThe asking rate has dipped under two per over now
#
# Gareth: "Bangladesh just lucky they batted first.
#
# working with Gareth
#
# Guptill looking like he could top his high score today if it was a first innings. "
#
# working with Guptill
#
# opening comm_part9.json
# Over the wicket for the final ball
#
# Matt: "This might be a good confidence booster for the blackcaps, but it's India they'll have to beat to win a world cup and the top order never looked good against their accuracy and pace.
#
# working with Matt
#
# "Just 15 more for New Zealand to make it 2-0
#
# TW: "NZ need to stick with Nicholls, Munro has been given more than a fair chance and has proven ordinary at best against quality attacks, if the slog sweep fails there is not much else in his arsenal.."Jez: "These two squashings haven't really helped sort out New Zealand's selection conundrums, the middle and lower order batting hasn't been tested at all.
#
# working with Nicholls
#
#
# working with Munro
#
# Will we see wholesale changes in game three?
# Will NZ look to bat first no matter what?
# "Mehidy againOnly nine more to goTh field comes upTime for the presentation:
#
# Guptill: There was a lot of flow and rhythm in that one.
#
# working with Mehidy
#
# Mehidy found
#
#
# working with Guptill
#
# Time spent in the middle in Napier helped me.
#
# working with Time
#
#
# working with Napier
#
# Mashrafe: Yea, it was a tough day.
# We lost early wickets, our partnerships were 30-odd, they could have been 60 and the match might have been different.
# Our top order has to step up little bit, Mithun has been scoring well, Mustafizur bowled well today.
#
# working with Mithun
#
# Mithun found
#
#
# working with Mustafizur
#
# Mustafizur found
#
# Not too many positives coming out from these matches.
# We have to play as a group, we scored 220-230 but we need to score 270-280 then we can fight it out
#
# Williamson: It was a really good performance; the guys are coming out and playing their roles.
#
# working with Williamson
#
# There was a little bit there for us with the overcast conditions and we did well to pick regular wickets.
# We learnt some harsh lessons against India as individuals.
# We've seen Nice performances in the last two matches, especially from Guptill in terms of taking the momentum from the previous game.
# Scoring back-t-back hundreds is freakish.
# It was nice to spend some time in the middle and I wanted to play straight and I wanted to assist his freedom.
# Just to confirm: Williamson has been rested for the third ODI, Colin Munro will play in his place.
#
# working with Williamson
#
#
# working with Colin Munro
#
# Tom Latham will captain the side in that match in Dunedin.
#
# working with Tom
#
#
# working with Dunedin
#
# That's it from the second ODI then, from me, Vishal Dikshit, and Varun Shetty.
#
# working with Vishal Dikshit
#
#
# working with Varun Shetty
#
# Isam's report will be up soon and there's more action left in the day so do plan you Saturday accordingly: the SA-SL Test and PSL later on.
#
# working with Test PSL
#
# Until then, goodbye and good luck!
# 5.57pm Taylor and Williamson come together to punch their gloves and then go on to shake hands with the Bangladesh team.
# Another comprehensive win for the hosts against Bangladesh, in very similar fashion as the first ODI.
#
# working with Bangladesh
#
# Bangladesh's batting is looking out of sorts against the accurate swing and pace bowling, their lower order (mainly Mithun) has saved them to cross a respectable 200 both times otherwise their batting hasn't clicked at all.
# And even while defending low totals, their bowling seems to lack that penetration or the threat a pace attack needs, especially in these conditions, to try and prepare for the World Cup.
# Bangladesh and New Zealand won't be playing more ODIs after this series until the global tournament in the summer.
#
# working with Bangladesh
#
# Not having Shakib for this series can't be the only reason for such a performance.
#
# working with Shakib
#
# Shakib found
#
# New Zealand will be feeling more confident about Guptill after the series loss against India.
#
# working with Guptill
#
# Guptill has two centuries in as many games and they must still be wondering whether Munro should open with him at the World Cup or Nicholls.
#
# working with Munro
#
# Their lower order still hasn't been tested but having both Neesham and de Grandhomme in the squad bodes well for them.
#
# working with Neesham
#
# opening comm_part3.json
# Shoaib : "Saifuddin has complicated matters by batting Well.
#
# working with Saifuddin
#
# Saifuddin found
#
# Logically he's the one that should make way for Rubel.
#
# working with Logically
#
#
# working with Rubel
#
# And Shakib's injury is like losing 2 players for BD.
#
# working with Shakib
#
# Shakib found
#
# "BowlingGreggy : "Bangladesh must be sick of the sight of Guptill.
#
# working with Guptill
#
# Remember when he was out of form?
# (It was last week)"Aayan: "Ohhhh gosh!
# Come on BD Let's make a match of it.
# "Goes aroundArik Shams: "Waking up at 4am in the morning, sleeping only 2hrs and watching this disappointed performance from Bangladesh team is really frustrating.
#
# working with Shams
#
# The way they are playing seems like they will have to learn cricket from the beginning.
# No spirit is shown on the field."
# opening comm_part2.json
# Roshan: "Albeit the under par total, B'desh should've taken this opportunity to bring in Rubel for Miraz, possibly.

# %% [markdown]
# # Next Step
# #### Create a function that takes in commetary json and spits out a dictionary that contains player names and commentary sentences about them
# ##### Better yet, make a function to evaluate a sentence first, then put a candidate sentence through it and get a result
# ### Okay, for simplicity let's work with <i style="color : red">postText</i>, <i style="color : red">preText</i> and give a scoring based on that
#     - have to add the save_player_names to this module

# %%
os.getcwd()

# %%
match_details

# %%
personal_comm
# Out:
# {'mashrafe mortaza': [[0.0,
#    'Mashrafe Mortaza gives his team a pep talk before the huddle disperses.'],
#   [0.0,
#    '<B>10.17am</b> <B>Toss - Bangladesh opt to field</b>, says Mashrafe Mortaza.'],
#   [-0.5106,
#    '<B>Bangladesh XI:</b> 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Mushfiqur Rahim (wk), 4 Mohammad Mithun, 5 Mahmudullah, 6, Mossaddek Hussain, 7  Sabbir Rahman, 8 Mohammed Saifuddin, 9 Mehidy Hasan Miraz, 10 Mashrafe Mortaza (capt), 11 Mustafizur Rahman\n\n<B>West Indies XI:</b> 1 Sunil Ambris, 2 Shai Hope (wk), 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Jason Holder (capt), 7 Fabian Allen, 8 Ashley Nurse, 9 Kemar Roach, 10 Ramon Reiffer, 11 Shannon Gabriel\n\nNitol: "That makes it three consecutive ODI final for Bangladesh without Shakib due to injury"\n\nSherwin graham: "Goodmornng, I think windies should try something different, take Bangladesh out of their comfort zone, the tigers have beaten windies twice batting second.'],
#   [0.7783,
#    "Same field as Mashrafe, pretty much.A little bit of nibble off the pitch, and the ball isn't quite coming on as well as the batsmen would like, just yet."],
#   [0.7251,
#    'If Mashrafe knew the match would be curtailed to 24 overs, surely he would bowl out his bowlers (not that his bowlers were doing particularly well here though)"\n\n\n\n\n\n<!--\nname: twitter\nurl: https://twitter.com/justinsmyth1/status/1129414310747357184\n-->\n\n\nNeeraj: "Forecast shows more chances of rain, how does it exactly look like right now ?'],
#   [0.6908,
#    '<b>Mashrafe Mortaza:</b> We have to play with some confidence, we need to back ourselves and our techniques.'],
#   [0.5574,
#    'Shashank Kishore heard <a href="http://www.espncricinfo.com/story/_/id/24760832/mashrafe-mortaza-irked-bcb-batting-reinforcements" target="_blank">Mashrafe Mortaza\'s lament</a> upon the lack of discussion on the selections, and Isam explored a question - <a href="http://www.espncricinfo.com/story/_/id/24761316/do-bangladesh-even-need-selectors" target="_blank">does Bangladesh even need selectors?</a><br><br>\n\n\n<b>2:40pm</b> Good afternoon and welcome back to our coverage of the Asia Cup.'],
#   [0.0,
#    'We have to bring our A-game for the Pakistan match.<br><br>\n\n<b>Mahmudullah is the Man of the Match.</b>\n\n<b>Mashrafe:</b> End of the match, Mustafiz was a magician.'],
#   [0.0, '"Mashrafe back.'],
#   [0.3612,
#    'They have made another change on the bowling front: Chameera replaces Praeep\n\n<strong>Mashrafe</strong>: We will like to bat first.'],
#   [0.8658,
#    '), Abul Hasan, Mustafizur, Rubel\n\nRandheer: "Bangladesh\'s rise to the top has been amazing.They have a good core around Tamim,Shakib and Rahim in their batting unit and the likes of Mortaza\'s experience in the bowling unit is important for B\'desh to cash in " --- Indeed, <a href="http://www.espncricinfo.com/story/_/id/22196737/bangladesh-seniors-boosting-their-side-dinesh-chandimal" target="_blank">Bangladesh\'s seniors are boosting their side</a>.'],
#   [0.0, 'Mashrafe wanted more from the middle order.'],
#   [0.0, '<b>Mashrafe</b>: Tamim and Shakib have been scoring runs.'],
#   [0.25,
#    'Mashrafe from round the wicketTaylor just four away from his fiftyTony: "NZ a hot chance for the World Cup?"'],
#   [-0.8173,
#    '"srk: "@Naim Noor Arnab: I really doubt that, especially with the ball, Mortaza is no longer wkt taking option, if FIZZ has bad day, it gets reflected at team scoring 300"'],
#   [0.5719,
#    '<b>2.05pm</b> Mashrafe Mortaza has won the toss and <b>Bangladesh are bowling first</b>.'],
#   [0.6124,
#    "High chances of the overcast conditions - it's pretty dark and menacing in the backdrop - having a say in Mashrafe's decision."],
#   [0.4404,
#    '<b>West Indies:</b> 1 Chris Gayle, 2 Evin Lewis, 3 Shai Hope (wk), 4 Jason Mohammed, 5 Shimron Hetmyer, 6 Jason Holder (capt), 7 Rovman Powell, 8 Devendra Bishoo, 9 Keemo Paul, 10 Ashley Nurse, 11 Alzarri Joseph\n\n<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Anamul Haque, 3 Sabbir Rahman, 4 Mushfiqur Rahim (wk), 5 Shakib Al Hasan 6 Mahmudullah, 7 Mosaddek Hossain, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Rubel Hossain, 11 Mustafizur Rahman\n\nwcpak: "@AG: Do you see any changes in the team composition?"'],
#   [0.0,
#    'Adnan Nizhum: "From the beginning of his captaincy, Mashrafe is underestimating bowler Mahmudullah.'],
#   [0.7089,
#    '<b>Bangladesh</b>: 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Sabbir Rahman, 8 Mashrafe Mortaza, 9 Mehidy Hasan Miraz, 10 Abu Jayed (ODI debut), 11 Mustafizur Rahman\n\n<b>West Indies</b>: 1 Shai Hope, 2 Sunil Ambris, 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Jason Hodler, 7 Fabian Allen, 8 Ashley Nurse, 9 Sheldon Cottrell, 10 Kemar Roach, 11 Raymon Reifer (ODI debut)\n\n<b>Mohammad Isam says</b>: "It is quite interesting to see the Bangladesh team management pick Abu Jayed, who was, a couple of days ago, being considered to be replaced by Taskin Ahmed in Bangladesh\'s main World Cup squad.'],
#   [0.0772,
#    'However, in the broader context, it will also be a challenge for Mashrafe bin Mortaza and his troops to maintain their consistency as a unit ahead of the ICC World Cup.'],
#   [0.0772,
#    'However, in the broader context, it will also be a challenge for Mashrafe bin Mortaza and his troops to maintain their consistency as a unit ahead of the ICC World Cup.'],
#   [0.5994,
#    'To me it is obvious play Mashrafe as long as he is fit and is willing to play."'],
#   [0.6808,
#    '"West Indies have a place in the final sealed and Bangladesh will meet them if they win this game and seeing how the first innings has gone, Mashrafe Mortaza will fancy his chances.'],
#   [-0.743,
#    '"Shivam: "Bangladesh should complete the quota of Abu Jayed and see how he bowls in the death overs... otherwise no point of him being in the team and world cup squad"Syed Kabir: "Every single game I see atleast one comment here criticizing Mashrafe\'s ability and every single time he delivers with crucial wickets.'],
#   [0.2732,
#    '------ Mohammad Isam has a reply for you: ""Mashrafe knows it all too well.'],
#   [0.4927,
#    '<b>Mashrafe Mortaza</b>: "The way we\'re playing, I think we bowled really well.'],
#   [0.5267,
#    'AnamBMDF : "Love the way BD have defeated WI today: bowling department led by Mashrafe, the captain, with crucial wickets supported by Mustafiz and spinners and during batting, it\'s a total team effort (all contribute significantly).'],
#   [0.128,
#    "Then their inspirational captain, Mashrafe Mortaza, who didn't nearly travel here because of his ill wife, did the rest."],
#   [0.7256,
#    'Ireland: 1 Paul Stirling, 2 James McCollum, 3, Andy Balbirnie, 4 William Porterfield (capt), 5 Kevin O\'Brien, 6 Mark Adair, 7 Gary Wilson (wk), 8 George Dockrell, 9 Boyd Rankin, 10 Barry McCarthy, 11 Josh Little\n\nBangladesh: 1 Tamim Iqbal, 2 Liton Das, 3 Shakib Al Hasan, 4 Mushfiqur Rahman, 5 Mahmudullah, 6 Mashrafe Mortaza, 7 Sabbir Rahman, 8 Rubel Hossain, 9 Abu Jayed, 10 Mosaddek Hossain, 11 Mohammad Saifuddin\n\nRamim: "Please don\'t try with bench strength cause Bangladesh will make it costlier by loosing one!! "'],
#   [0.0,
#    "<b>2.40pm</b> Talking of schedules, we had Pakistan captain Sarfraz Ahmed raise his concerns earlier and this time it's Bangladesh captain Mashrafe Mortaza."],
#   [0.8436,
#    '"Looks like Mehidy was going to continue but Mashrafe has decided to bring on Mosaddek nowNITESH PALIWAL: "This is very calm and smart inning build up by Afghanistan.'],
#   [0.0,
#    '<b>Mashrafe Mortaza</b>: Afghanistan outplayed us from the 40th over.'],
#   [0.8519,
#    "<strong>One change</strong>: Todd Astle comes in for Mitchell Santner\n\n<strong>Mashrafe Mortaza</strong>: We'd have liked to bowl first as well, still looks like a good track to bat on."],
#   [-0.4404, 'Has he fallen out of favor with Mortaza?'],
#   [-0.296, 'Mashrafe at No.'],
#   [-0.4767,
#    '<b>3.14pm</b> The Bangladesh players disperse from the huddle after some talk from Mashrafe, and the New Zealand openers stretch their arms while walking out.'],
#   [-0.128, '<b>Mashrafe</b>: Yea, it was a tough day.'],
#   [-0.3597,
#    'Really no one"<br><br>Back over the wicketjames: "@Jobaer: Who do you expect to replace Mashrafe as captain for the WC under such short notice?'],
#   [-0.4215,
#    '"<br><br>Jinder : "This could possibly be Mashrafe\'s last world cup anyways, but no one on the team has this much experience and charisma to captain the side apart from maybe Shakib.'],
#   [-0.3597,
#    'Once Mashrafe leaves, his presence will be greatly missing in the one day team.'],
#   [0.0,
#    '"<br><br>Back over the wicketGareth: ""This could possibly be Mashrafe\'s last world cup".'],
#   [0.4404,
#    "<b>West Indies:</b> 1 Chris Gayle, 2 Evin Lewis, 3 Shai Hope (wk), 4 Kieran Powell, 5 Shimron Hetmyer, 6 Jason Holder (capt), 7 Rovman Powell, 8 Devendra Bishoo, 9 Keemo Paul, 10 Ashley Nurse, 11 Sheldon Cottrell\n\n<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Anamul Haque, 3 Sabbir Rahman, 4 Mushfiqur Rahim (wk), 5 Shakib Al Hasan 6 Mahmudullah, 7 Mosaddek Hossain, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Rubel Hossain, 11 Mustafizur Rahman\n\nBangladesh's XI is unchanged."],
#   [-0.3182,
#    'Mortaza to Gayle.<br><br>\n\n<b>1.03pm</b> After controlling the game for 30 overs, West indies lost the plot towards the end to concede more than 150 runs in their last 20 overs.'],
#   [0.0,
#    "Tamim Iqbal's 11th hundred set the tone for Bangladesh, but it was Mahmudullah's breakneck fifty and Mashrafe's cameo that has taken them to their highest ever ODI score again West Indies."],
#   [0.5423,
#    '-- They\'re definitely due for one this seriesSoham Basak: "While Mashrafe played a gem of a knock, it seems a bit unfair to batsmen like Sabbir and Mosaddek, who have to get going from the first ball.'],
#   [0.5267,
#    '<b>Mashrafe Mortaza, the winning captain:</b> "Cricket is a mental game.'],
#   [0.5267,
#    'May be the situation demanded a promotion for Rovman Powell and Holder, just like Mashrafe promoted himself."'],
#   [0.2732,
#    'The camera stays on Mashrafe Mortaza, who starred with the bat late in the innings and then led with the ball as well.'],
#   [0.0,
#    'Around the wicketMJ Ahshan: "Mortaza 3-0 Lewis, Mortaza has dismissed Lewis in all 3 matches!'],
#   [0.296, 'Yep, "Shakib will bowl", says Mashrafe.'],
#   [0.4404,
#    '<strong>Bangladesh:</strong> 1 Tamim Iqbal, 2 Liton Das, 3 Imrul Kayes, 4 Soumya Sarkar, 5 Mushfiqur Rahim (wk), 6 Shakib Al Hasan, 7 Mahmudullah, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\n<strong>West Indies:</strong> 1 Kieran Powell, 2 Shai Hope (wk), 3 Darren Bravo, 4 Marlon Samuels, 5 Shimron Hetmyer, 6 Rovman Powell (capt), 7 Roston Chase, 8 Keemo Paul, 9 Devendra Bishoo, 10 Kemar Roach, 11 Oshane Thomas\n\nBangladesh have made five changes to their side, bringing in Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman, Mehidy Hasan Miraz and Rubel Hossain.'],
#   [-0.4939,
#    'he will be missed a lot :(" -- And Isam, right on cue, tells me this is <strong>Mashrafe\'s 200th ODI</strong>, 198 for Bangladesh and two for Asia XI.'],
#   [0.0, 'Mashrafe picked 3 for 30, Mustafizur ended with 3 for 35.'],
#   [0.0, '"Variations helped a lot," says Mashrafe.'],
#   [0.7506,
#    'Beautiful tight bowling and Mashrafe, what a persevering asset he has been for Bangladesh.'],
#   [0.6174,
#    'I thought the wicket was tough last game, but could have got there towards the end.<br><br>\n\n<b>Mortaza:</b> Looks to be a very good wicket.'],
#   [0.8176,
#    'By the way, this is <b>Mashrafe Mortaza\'s 30th win as ODI captain.</b> He <a href="http://stats.espncricinfo.com/ci/engine/records/individual/most_matches_as_captain.html?class=2;id=25;type=team" target="_blank">goes past</a> the previous highest of 29 wins by Habibul Bashar.'],
#   [0.0, "Here's <b>Mashrafe Mortaza</b>."],
#   [-0.0516,
#    'Shakib to continueMustafa Moudi: "Shakib tried hard to come closer in the Career Wickets to Mortaza, But even Mortaza is adamant to keep the gap unchanged.'],
#   [0.0,
#    'The XIs for you\n\n<strong>Bangladesh:</strong> 1 Liton Das, 2 Imrul Kayes, 3 Fazle Mahmud, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Mehidy Hasan Miraz, 8 Mohammad Saifuddin, 9 Mashrafe Mortaza (capt), 10 Nazmul Islam, 11 Mustafizur Rahma<strong>n\n\nZimbabwe:</strong> 1 Hamilton Masakadza (capt), 2 Cephas Zhuwao, 3 Craig Ervine, 4 Brendan Taylor (wk), 5 Sean Williams, 6 Peter Moor, 7 Sikandar Raza, 8 Donald Tiripano, 9 Brandon Mavuta, 10 Kyle Jarvis, 11 Tendai Chatara\n\n<b>30-year old Fazle Mahmud debuts for Bangladesh.'],
#   [-0.2755,
#    'Mashrafe and Mushfiqur have only recently recovered from injuries sustained in the same tournament, and neither is 100% fit.'],
#   [0.3612,
#    "Can Bangladesh push to 280?<b>6.20pm</b> It looked like Mashrafe Mortaza's fears about the unpredictability of the Mirpur pitch came true when Kyle Jarvis' three-wicket burst reduced them to 139 for 6 in the 30th over."],
#   [0.0,
#    'Mashrafe Mortaza has got the new ball.Mehidy Hasan from the other endAround the wicketBack to around the wicket to the left-handerAround the wicket'],
#   [0.0,
#    'Mashrafe Mortaza has got the new ball.Mehidy Hasan from the other endAround the wicketBack to around the wicket to the left-handerAround the wicket'],
#   [0.8271,
#    "<strong>Toss: Bangladesh have opted to bat first </strong>\n\n<strong>New Zealand</strong>: 1 Martin Guptill, 2 Henry Nicholls, 3 Kane Williamson (capt), 4 Ross Taylor, 5 Tom Latham (wk), 6 Jimmy Neesham, 7 Colin de Grandhomme, 8 Mitchell Santner, 9 Lockie Ferguson, 10 Matt Henry, 11 Trent Boult\n\nSo compared to the fifth ODI v India, they bring in the fit Martin Guptill for Munro, and Lockie Ferguson for Todd Astle\n\n<strong>Bangladesh</strong>: 1 Tamim Iqbal, 2 Liton Das, 3 Soumya Sarkar, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Sabbir Rahman, 8 Mohammad Saifuddin, 9 Mehidy Hasan Miraz, 10 Mashrafe Mortaza (capt), 11 Mustafizur Rahman\n\nThey've brought in Sabbir for Shakib\n\n<b>1.25pm</b> The players are warming up, it's nice and sunny because of the open blue skies at McLean Park."],
#   [-0.2023,
#    '[Starting a new series] is just going back to basics and today was a good example of that.<br><br>\n\n\n<b>Mashrafe Mortaza:</b> Struggled with the bat, lost too many wickets at the start.'],
#   [0.4215,
#    '<strong>Bangladesh:</strong> Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>New Zealand:</strong>: Martin Guptill, Colin Munro, Kane Williamson (capt), Ross Taylor, Tom Latham (wk), James Neesham, Colin de Grandhomme, Mitchell Santner, Matt Henry, Lockie Ferguson, Trent Boult\n\n<strong>Mashrafe</strong>: Would have liked to bowl.'],
#   [0.4215,
#    '<strong>Bangladesh:</strong> Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>New Zealand:</strong>: Martin Guptill, Colin Munro, Kane Williamson (capt), Ross Taylor, Tom Latham (wk), James Neesham, Colin de Grandhomme, Mitchell Santner, Matt Henry, Lockie Ferguson, Trent Boult\n\n<strong>Mashrafe</strong>: Would have liked to bowl.'],
#   [-0.3612,
#    '<strong>Mashrafe</strong>: it was a good wicket, we were 20-30 short, the outfield was slow, I think we lost too many wickets after people getting set and getting out.'],
#   [-0.3724,
#    '<b>Pakistan:</b> Fakhar Zaman, Imam Ul Haq, Babar Azam, Sarfraz Ahmed (c, wk), Shoaib Malik, Asif Ali, Shadab Khan, Mohammad Nawaz, Hasan Ali, Junaid Khan, Shaheen Shah Afridi\n\n<b>Bangladesh:</b> Liton Das, Soumya Sarkar, Mohammad Mithun, Mushfiqur Rahim (wk), Mominul Haque, Imrul Kayes, Mahmudullah, Mashrafe Mortaza (c), Mehidy Hasan, Rubel Hossain, Mustafizur Rahman\n\nInteser: "Shakib not playing is a huge blow.'],
#   [0.34,
#    'A bit of a break in play as Mashrafe gets a new set of gloves.Three overs to go.'],
#   [0.2023,
#    '"Chowdhury Sayee: "Bad move by Soumya, keeping Shadab was better "<b>Required run rate touches 6</b><b>Mohammad Isam:</b> Mashrafe has now played against both Inzamam and Imam.'],
#   [0.5267,
#    '<b>Mashrafe Mortaza, the winning captain:</b> "I think we changed our combination a bit.'],
#   [0.0, '"Here\'s Mashrafe.'],
#   [0.4201, 'I wonder if Mashrafe is fully fit.'],
#   [0.4404,
#    'around the wicket to ImamHere\'s Mahmudullah.Salman: "Looks good to see Mashrafe back on the field.'],
#   [0.3094, 'Anand: "Is Mortaza okay ??'],
#   [-0.1027,
#    'Mashrafe Mortaza now wants to <a href="http://www.espncricinfo.com/story/_/id/22222422/mashrafe-hoping-set-record-straight-shere-bangla" target="_blank">set the record straight</a> and ease the painful memories.'],
#   [0.0,
#    '<b>Bangladesh XI</b>: 1 Tamim Iqbal, 2 Mohammad Mithun, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mahmudullah, 6 Sabbir Rahman, 7 Mohammad Saifuddin, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\nOne change for Sri Lanka: Shehan Madushanka replaces Lakshan Sandakan.'],
#   [0.6249,
#    'More about what you need to look ahead to in <a href="http://www.espncricinfo.com/series/8631/preview/1130743/" target="_blank">Andrew Fernando\'s preview</a> as we wait for the toss and teams.sl_coder: "Hope Asela Gunaratne will show some colors today, "Mashrafe brings himself on from the other end.Tharaka 1008: "If this opening pair can survive til 15 overs without unnecessary hurry and shots for Bangladesh RIP "Zeeshan Mahmud: "Watching Miraz is like solving a chess problem.'],
#   [0.4939,
#    '"I think the bowling has been pretty good", says <b>Bangladesh captain Mashrafe Mortaza</b>.'],
#   [0.0,
#    '"Tasmeem: "I think Mashrafe should have come to bat before both Miraz and Saifuddin.'],
#   [-0.4215,
#    'Well, <a href="http://www.espncricinfo.com/story/_/id/24739665/how-dhoni-masterstroke-turned-kedar-jadhav-career-around" target="_blank"><b>cause MS Dhoni had a masterstroke</b></a>.<br><br>\n\n<b>India</b>: 1 Rohit Sharma (capt), 2 Shikhar Dhawan, 3 Ambati Rayudu, 4 Dinesh Karthik, 5 MS Dhoni (wk), 6 Kedar Jadhav, 7 Ravindra Jadeja, 8 Bhuvneshwar Kumar, 9 Kuldeep Yadav, 10 Jasprit Bumrah, 11 Yuzvendra Chahal<br><br>\n\n<b>Bangladesh</b>: 1 Liton Das, 2 Nazmul Hossain, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Mosaddek Hossain, 8 Mehidy Hasan, 9 Mashrafe Mortaza (capt), 10 Rubel Hossain, 11 Mustafizur Rahman<br><br>\n\nMohammad Isam has found out that "<b>This will only be <a href="http://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;filter=advanced;opposition=6;orderby=start;player_involve=48391;player_involve_type=none;spanmin1=01+Feb+2007;spanval1=span;team=25;template=results;type=team;view=results" target="_blank">the second time</a> Tamim will miss an ODI against India since his debut in 2007</b>.'],
#   [0.0258,
#    'Ravindra jadeja comes in for the injured Hardik Pandya</b>"<br><br>\n\n"Would have liked to bat anyway," says Mashrafe Mortaza.'],
#   [0.3182,
#    'Would that come out as a major advantage, especially considering Mashrafe Mortaza and his team played a game yesterday in Abu Dhabi and are now back in action again in Dubai?<bR><br>\n\nZeeshan: "I don\'t really think it\'s going to be a major advantage for India considering the fact that the travel time is less than a couple of hours.'],
#   [0.0,
#    '"<br><br>\n\n<b>Bangladesh:</b> Liton Das, Soumya Sarkar, Mohammad Mithun, Mushfiqur Rahim (wk), Imrul Kayes, Mahmudullah, Mehidy Hasan, Mashrafe Mortaza (capt.'],
#   [0.3818,
#    "<b>Mashrafe:</b> Credit goes to the boys, the way they've behaved and stoof up the last few matches."],
#   [0.1027,
#    'And this is technically an ACC tournament.Saad : "Strange bowling changes by Mashrafe" -- yep, six taken off this over.'],
#   [0.0, '<b>Mashrafe Mortaza</b> collects the runners-up cheque.'],
#   [0.5859, 'Fizz returns.Siddharth: "Brilliant captaincy by Mashrafe.'],
#   [0.3612,
#    "That's strange, because Mashrafe is ready at the top of his mark."],
#   [0.0, 'Mashrafe has changed his mind at the last moment.'],
#   [0.7906,
#    'Here are the XIs - \n\n<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Anamul Haque, 3 Shakib Al Hasan, 4 Mahmudullah, 5 Mushfiqur Rahim (wk), 6 Nasir Hossain, 7 Sabbir Rahman, 8 Mashrafe Mortaza (capt), 9 Rubel Hossain, 10 Sunzamul Islam, 11 Mustafizur Rahman\n\n<b>Zimbabwe</b>: 1 Hamilton Masakadza, 2 Solomon Mire, 3 PJ Moor (wk), 4 Brendan Taylor, 5 Craig Ervine, 6 Sikandar Raza, 7 Malcolm Waller, 8 Graeme Cremer (capt), 9 Kyle Jarvis, 10 Tendai Chatara, 11 Blessing Muzarabani\n\n<b>11.30 am Bangladesh have won the toss and have decided to bowl</B><br><br>\n\nBangladesh captain Mashrafe Mortaza, as he has often done, <a href="http://www.espncricinfo.com/story/_/id/22094239/mashrafe-mortaza-backs-pace-heavy-plan" target="_blank">is backing his fast bowlers</a> to make an impact.'],
#   [0.7906,
#    'Here are the XIs - \n\n<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Anamul Haque, 3 Shakib Al Hasan, 4 Mahmudullah, 5 Mushfiqur Rahim (wk), 6 Nasir Hossain, 7 Sabbir Rahman, 8 Mashrafe Mortaza (capt), 9 Rubel Hossain, 10 Sunzamul Islam, 11 Mustafizur Rahman\n\n<b>Zimbabwe</b>: 1 Hamilton Masakadza, 2 Solomon Mire, 3 PJ Moor (wk), 4 Brendan Taylor, 5 Craig Ervine, 6 Sikandar Raza, 7 Malcolm Waller, 8 Graeme Cremer (capt), 9 Kyle Jarvis, 10 Tendai Chatara, 11 Blessing Muzarabani\n\n<b>11.30 am Bangladesh have won the toss and have decided to bowl</B><br><br>\n\nBangladesh captain Mashrafe Mortaza, as he has often done, <a href="http://www.espncricinfo.com/story/_/id/22094239/mashrafe-mortaza-backs-pace-heavy-plan" target="_blank">is backing his fast bowlers</a> to make an impact.'],
#   [0.4404,
#    '<b>Mashrafe Mortaza</b>, the winning captain: "South Africa was tough.'],
#   [0.205,
#    '<strong>Teams</strong> - <strong>Bangladesh: </strong>Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>South Africa:</strong> Quinton de Kock (wk), Aiden Markram, Faf du Plessis (c), Rassie van der Dussen, David Miller, JP Duminy, Andile Phehlukwayo, Chris Morris, Kagiso Rabada, Lungi Ngidi, Imran Tahir\n\n<strong>Faf du Plessis</strong>: "We\'re playing the extra seamer today so we want to try and attack Bangladesh with some extra pace.'],
#   [0.2023, '<strong>Mashrafe Mortaza:</strong> "I\'m fine.'],
#   [0.0, 'The skipper, Mashrafe Mortaza returns.'],
#   [-0.0516,
#    'Unless you rattle him early.. he gets into a rhythm that not many can break out from...."Tasmeem: "Need some good overs from Mashrafe.'],
#   [0.7027,
#    "<b> Mashrafe Mortaza: </b> We were pleased to bat first, after the toss, yes there was some doubt but we knew this was a used wicket, so batting wouldn't be a bad option."],
#   [0.7964,
#    'This one is an emphatic win by a much-confident side led by a tactically astute and inspirational captain in Mashrafe Mortaza.'],
#   [-0.0516,
#    '3Shakib is into the attackTrihan: "Good captaincy from Mashrafe to bring in Shakib and attack Du Plessis.'],
#   [0.3818,
#    '<b>2.29pm</b> The openers are walking out, and it looks like Mashrafe Mortaza will have the ball in hand.'],
#   [0.2023,
#    'The playing XIs for you\n\n\n<strong>Bangladesh:</strong> 1 Liton Das, 2 Imrul Kayes, 3 Fazle Mahmud, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Mehidy Hasan Miraz, 8 Mohammad Saifuddin, 9 Mashrafe Mortaza (capt), 10 Nazmul Islam, 11 Mustafizur Rahman\n\n<strong>Zimbabwe:</strong> 1 Hamilton Masakadza (capt), 2 Cephas Zhuwao, 3 Brendan Taylor (wk), 4 Sean Williams, 5 Peter Moor, 6 Elton Chigumbura, 7 Sikandar Raza, 8 Donald Tiripano, 9 Brandon Mavuta, 10 Kyle Jarvis, 11 Tendai Chatara\n\n\nIsam with a golden nugget: "This is the first time in 16 years that a Chittagong player doesn\'t feature in an ODI in Chittagong."'],
#   [0.6597,
#    "Looks like a good bet to be Mashrafe's replacement if he continues."],
#   [-0.4767,
#    'Don\'t know why Mashrafe hasn\'t brought Apu into the attack yet."'],
#   [0.25,
#    'Credit to him for cleverly mixing it up and coming back strongAhasan: "Mashrafe is occasionally a wicket taking bowler in death overs.'],
#   [0.5267,
#    '<b> Mohammad Saifuddin </b> is Player of the Match for his three-wicket haul\n\n<b> Mashrafe Mortaza: </b> Winning the toss was crucial.'],
#   [0.4215,
#    'Chayon: "@jai, No matter what happens "Tamim, Shakib, Mushfique, Mahmudullah & Mashrafe" are auto choice, if they are fit to play.'],
#   [0.0,
#    "Meanwhile, this is also <strong>Mashrafe Mortaza's 200th ODI for Bangladesh</strong>."],
#   [0.0,
#    '<strong>Bangladesh: </strong>1 Tamim Iqbal, 2 Liton Das, 3 Soumya Sarkar, 4 Mushfiqur Rahim (wk), 5 Shakib Al Hasan, 6 Mohammad Mithun, 7 Mahmudullah, 8 Mohammad Saifuddin, 9 Mehidy Hasan Miraz, 10 Mashrafe Mortaza (capt), 11 Mustafizur Rahman\n\nTwo changes for the home side.'],
#   [0.5777,
#    'Mushfiqur told Mashrafe that I should bowl when Hetmyer came in to bat, so thanks to Mushy."'],
#   [0.7579,
#    'Finally, we have winning captain <b>Mashrafe Mortaza</b> speaking to raucous cheers from the crowd.'],
#   [0.4588,
#    '<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Liton Das, 3 Imrul Kayes, 4 Soumya Sarkar, 5 Mushfiqur Rahim (wk), 6 Shakib Al Hasan, 7 Mahmudullah, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\n<b>12.08pm</b> Hello and welcome to the second ODI between Bangladesh and West Indies.'],
#   [0.3252,
#    '<b>9.17 pm</b> <b>Mashrafe Mortaza:</b> "It was a 50-50 match at the end, but we couldn\'t hold the pressure.'],
#   [0.4404, 'Good decision by Mortaza to not review the previous over.'],
#   [0.7043,
#    'And Shakib will bowl nowSajid: "Mashrafe played 200 ODIs in his 17 years career but Shai hope already palyed 42 ODis in his two years career!'],
#   [0.5859,
#    'West Indies are losing their way, with nobody sticking around with Shai Hope, who has been fantasticZahid: "@Sajid: Mashrafe had his fair share of injuries.'],
#   [0.34, "Bangladesh has played 310 ODI's since Mashrafe's ODI debut."],
#   [0.296,
#    '(I\'m a die-hard Bangladeshi fan)" -- Would agree, though the positive is that Mashrafe Mortaza handed the ball to relatively inexperienced bowlers at the death, and Saifuddin and Hider between them conceded just seven off the last two overs.'],
#   [0.8481,
#    'Recent top order form is a positive sign for Mashrafe\'s men.Here\'s Ngarava from the other end.Chayon: "What is the highest successful run chase for Bangladesh in ODIs, Akshay?"'],
#   [0.0,
#    '<b>Bangladesh XI</b>: Bangladesh: 1 Tamim Iqbal, 2 Anamul Haque, 3 Shakib Al Hasan, 4 Mahmudullah, 5 Mushfiqur Rahim (wk), 6 Nasir Hossain, 7 Sabbir Rahman, 8 Mohammad Saifuddin, 9 Mashrafe Mortaza (capt), 10 Rubel Hossain, 11 Mustafizur Rahman\n\nTwo changes for Sri Lanka.'],
#   [0.7003,
#    '"Pace from the other end: captain Mashrafe MortazaMendisHossen: "what could be better gift than a wicket in his second over from an irregular bowler for a captain introducing very first?'],
#   [0.7003,
#    'Mashrafe to continue.Aminul : "Mashrafe Mortaza the old fellow impress everyone , We hope he continues his career for another 4-5 years "'],
#   [0.0,
#    'Mashrafe and Rubel, the seamers, complemented him by taking two wickets each.'],
#   [0.836,
#    '<b>Mashrafe Mortaza</b>: "If you look at recent past, this is one of the best wins for us.'],
#   [0.4215, 'Mortaza over the wicketTamim was inspiring indeed.'],
#   [0.743,
#    '<b>Mashrafe Mortaza, the winning captain</b> says: "Thanks to Mushfiqur and Mithun.'],
#   [0.6486,
#    '<b>West Indies:</b> 1 Shane Dowrich, 2 Shai Hope (wk), 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Sunil Ambris, 7 Ashley Nurse, 8 Jason Holder (capt), 9 Kemar Roach, 10 Sheldon Cotterell, 11 Shannon Gabriel\n\n<b>Bangladesh:</b> 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Sabbir Rahman, 8 Mohammad Saifuddin, 9 Mashrafe Mortaza, 10 Mehidy Hasan Miraz, 11 Mustafizur Rahman\n\nBrandon : "Excited for a close contest between two evenly matched ODI teams.'],
#   [0.2732,
#    'Mashrafe Mortaza dismissed both in the space of three balls, across two overs, and then got rid of Jason Holder as well.'],
#   [0.2732,
#    'Mashrafe Mortaza dismissed both in the space of three balls, across two overs, and then got rid of Jason Holder as well.']],
#  'shakib al hasan': [[0.0,
#    'Vinod Rajpal: "Was awaiting for Shakib\'s 250th ODI wicket from last 2 ODIs....now have to wait till 2nd of June !!"'],
#   [0.0, 'They should, even without Shakib.'],
#   [0.832,
#    'Liton Das and Abu Jayed, their best batsman and their best bowler from last match not in playing XI with their star man Shakib rested.'],
#   [0.0, 'But <B>no Shakib</b>, still recovering from a back spasm.'],
#   [-0.5106,
#    '<B>Bangladesh XI:</b> 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Mushfiqur Rahim (wk), 4 Mohammad Mithun, 5 Mahmudullah, 6, Mossaddek Hussain, 7  Sabbir Rahman, 8 Mohammed Saifuddin, 9 Mehidy Hasan Miraz, 10 Mashrafe Mortaza (capt), 11 Mustafizur Rahman\n\n<B>West Indies XI:</b> 1 Sunil Ambris, 2 Shai Hope (wk), 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Jason Holder (capt), 7 Fabian Allen, 8 Ashley Nurse, 9 Kemar Roach, 10 Ramon Reiffer, 11 Shannon Gabriel\n\nNitol: "That makes it three consecutive ODI final for Bangladesh without Shakib due to injury"\n\nSherwin graham: "Goodmornng, I think windies should try something different, take Bangladesh out of their comfort zone, the tigers have beaten windies twice batting second.'],
#   [0.0,
#    '-- Hey, we understand that a call on Shakib will be taken today morning.'],
#   [-0.5423,
#    'West Indies are looking to avoid a third-straight loss at the hands of Bangladesh in the tournament, while the <i>Tigers</i> may be without Shakib Al Hasan today.'],
#   [0.3182,
#    'I am sure that was International one day because Shakib\'s 134* against Canada is still his career best."'],
#   [0.5341,
#    "It wasn't easy, with Shakib unavailable, but they were terrific in the last four overs of West Indies' innings after which their batsmen kept the tempo going through the innings."],
#   [0.0,
#    '"<br><br>\n\n<b>Bangladesh XI:</b> Liton Das, Nazmul Shanto, Shakib Al Hasan, Mushfiqur Rahim (wk), Mahmudullah, Imrul Kayes, Mohammad Mithun, Mahsrafe Mortaza (capt.'],
#   [0.25,
#    "And the fielding wasn't very hot, though Shenwari's direct hit to run out Shakib was superb."],
#   [-0.6478,
#    '"And with that, the required rate has touched run-a-ball.Nayeem: "Is Shakib carrying any kind of injury or Mash keeping his main weapon in his sleeves for the later part of the match?"'],
#   [0.6114,
#    '69 off 48 still looks gettable, but Shakib is marking his run-up now.Around the wicketAvik Aravind : "Is it just me or is there anyone else that agrees that Rashid Khan should have come in as a pinch hitter" --- SpaceX has just received a message from Mars asking for this.James De Lamber: "This one\'s looking tense... you\'d think it\'s advantage Afghanistan but Bangladesh are holding their nerve here!'],
#   [0.3384,
#    "Hadn't given up - Shakib bowled really well in his last three balls."],
#   [0.0, 'It will be Shakib.'],
#   [0.0,
#    '), Gunaratne, Dickwella(wk), Perera, Lakmal, Sandakan, Dananjaya, Chameera\n\n<strong>Bangladesh</strong>: Tamim, Anamul, Shakib, Mushfiqur (wk), Mahmudullah, Sabbir, Nasir, Mashrafe (capt.'],
#   [0.0, 'raining sixes here..."Shakib comes onSandeep: "@Showkat Khan.'],
#   [0.0258,
#    'Wonder what they\'re discussing there.Mushfiqur has a bandaged wrist now.Abdullah: "How one player can make a huge difference, Bangladesh is missing Shakib so much.'],
#   [0.0,
#    'Arif Hossain: "Shakib Al Hasan should be allowed to ball in the first powerplay.'],
#   [0.0,
#    '"<strong>Andre Russell is seen nursing his left hamstring with ice</strong>Here\'s Shakib'],
#   [0.7089,
#    '<b>Bangladesh</b>: 1 Tamim Iqbal, 2 Soumya Sarkar, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mohammad Mithun, 6 Mahmudullah, 7 Sabbir Rahman, 8 Mashrafe Mortaza, 9 Mehidy Hasan Miraz, 10 Abu Jayed (ODI debut), 11 Mustafizur Rahman\n\n<b>West Indies</b>: 1 Shai Hope, 2 Sunil Ambris, 3 Darren Bravo, 4 Roston Chase, 5 Jonathan Carter, 6 Jason Hodler, 7 Fabian Allen, 8 Ashley Nurse, 9 Sheldon Cottrell, 10 Kemar Roach, 11 Raymon Reifer (ODI debut)\n\n<b>Mohammad Isam says</b>: "It is quite interesting to see the Bangladesh team management pick Abu Jayed, who was, a couple of days ago, being considered to be replaced by Taskin Ahmed in Bangladesh\'s main World Cup squad.'],
#   [-0.6124,
#    "I don't think either team will be too unhappy with how things have gone so far.Another change, here's Shakib Al Hasan, left-arm round to Chase.Jonathan Carter walks in at No."],
#   [0.6114,
#    '"James: "Shakib\'s first 8 overs (0/18) would look like good control in test cricket, let alone ODI\'s"<!--\nname: twitter\nurl: https://twitter.com/andymcg_cricket/status/1127916825709170690\n-->Nitish: "@Mr. Al: Does ESPNCricinfo have an accessible archive on the number of dot balls bowled in an innings ?'],
#   [0.0,
#    'Their overall run-rate is only 4.68Vinod Rajpal: "With Shakib\'s 10 over quota, he becomes the 2nd Bangladeshi to bowl 10,019 ODI deliveries.."'],
#   [0.93,
#    "Add to that Shakib's brilliant spell 10-1-27-1 and Mehidy's beautiful control and they've had a pretty good day in the sun."],
#   [0.0,
#    "It's because the experiences of Tamim, Shakib, Mushfiq, Mahmudullah and Mashrafi (5 *)."],
#   [-0.296, '"Shakib Al Hasan walks in at No.'],
#   [0.0,
#    'Mash and Shakib can controll the run flow while it will probably be Mustafiz and Mehidy that the opposition will target to take on.'],
#   [-0.5621,
#    '"Shakib takes fresh guard.Make no mistake, this isn\'t the easiest of surfaces to bat on.'],
#   [0.0, 'Tamim and Shakib took way too long to switch gears.'],
#   [0.0,
#    'When that intent finally came, from Shakib first, he perished short of his hundred.. Tamim went on to get one.. the <b>slowest hundred by a Bangladesh batsman in ODIs</b>.'],
#   [0.6124,
#    'Shakib made 97, Tamim batted right through to top score with 131 and Mushfiqur played a fine cameo that helped Bangladesh blast 43 off the last two overs.'],
#   [0.7256,
#    'Ireland: 1 Paul Stirling, 2 James McCollum, 3, Andy Balbirnie, 4 William Porterfield (capt), 5 Kevin O\'Brien, 6 Mark Adair, 7 Gary Wilson (wk), 8 George Dockrell, 9 Boyd Rankin, 10 Barry McCarthy, 11 Josh Little\n\nBangladesh: 1 Tamim Iqbal, 2 Liton Das, 3 Shakib Al Hasan, 4 Mushfiqur Rahman, 5 Mahmudullah, 6 Mashrafe Mortaza, 7 Sabbir Rahman, 8 Rubel Hossain, 9 Abu Jayed, 10 Mosaddek Hossain, 11 Mohammad Saifuddin\n\nRamim: "Please don\'t try with bench strength cause Bangladesh will make it costlier by loosing one!! "'],
#   [-0.872,
#    "Tamim was his usual self, but they will be concerned with Shakib's side strain that forced him to retire hurt."],
#   [0.765,
#    "Here's something from another match-winner: \n\n<b>Shakib Al Hasan</b>: Mushfiqur played a tremendous knock, probably his best in ODI."],
#   [0.3612,
#    '"Here\'s Shakib for the first time\n\nSuresh Guna: "With proper exposure, the assosciates can do wonders like what HK did the other day against India.'],
#   [0.6249,
#    'Shakib has three, Afghanistan five down, here\'s NabiOnly two runs and a wicket in Shakib\'s last two oversRamas: "230 will be great score for Afghanistan to defend with their bowlers" Long way to go from hereIt\'s time for some drinks.'],
#   [0.2023,
#    'Shakib has stifled the Afghanistan middle order here with three wickets, still 15 overs to go and only five wickets in hand.'],
#   [0.3612,
#    'At one point it looked like Shakib was taking the match away from them with his stifling lines and four wickets in the first innings.'],
#   [0.2846,
#    "Mohammad Mithun came to the rescue yet again but the batsmen before him will have to take more responsibility going forward, especially in Shakib's absence."],
#   [0.0,
#    "Not having Shakib for this series can't be the only reason for such a performance."],
#   [-0.4404, "And Shakib's injury is like losing 2 players for BD."],
#   [0.0,
#    "Don't think having any of the other Big 3 as captain, including Shakib, would change the outcome of this series."],
#   [-0.4215,
#    '"<br><br>Jinder : "This could possibly be Mashrafe\'s last world cup anyways, but no one on the team has this much experience and charisma to captain the side apart from maybe Shakib.'],
#   [-0.1872,
#    'Could be something to do with his T20I record in Asia: 21 innings, 431 runs, strike rate of 113, only one half-century, average 20.50Now Saifuddin comes backShan: "Playing the BPL days before this tour isn\'t ideal preparation considering that most of the players are used to the conditions back home, but you\'d really think that the other seniors would turn up with or without Shakib.'],
#   [-0.0516,
#    'I swear I\'ll retweet your campaign.MahneelMusa: "What is going to happen to Bangladesh cricket after Tamim, Shakib, Mushfiq, Mahmudullah and Mashrafe retire?'],
#   [0.4404, '"Davo from Guyan: "Thanks Shakib...sincerely, every West Indian.'],
#   [0.4404,
#    'Worth bowling Shakib though...Manan: "Hope doesn\'t deserve a place in any limited over sides.'],
#   [0.6597,
#    'Scored a hundred in his last outing.Davo from Guyan: "I think many here would agree with me that Hope just got Gayle\'s wicket......."Gayle\'s gone, and here comes Shakib Al Hasan.'],
#   [-0.4767, '"Sajib: "It\'s a shame Shakib is still wicketless today.'],
#   [0.296, 'Yep, "Shakib will bowl", says Mashrafe.'],
#   [0.3182,
#    'Should be rotated soon "Hasan replaces Hossain.Davo from Guyan: "Calm down guys... bare in mind here, these boundaries are very small.'],
#   [0.4404,
#    '<strong>Bangladesh:</strong> 1 Tamim Iqbal, 2 Liton Das, 3 Imrul Kayes, 4 Soumya Sarkar, 5 Mushfiqur Rahim (wk), 6 Shakib Al Hasan, 7 Mahmudullah, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\n<strong>West Indies:</strong> 1 Kieran Powell, 2 Shai Hope (wk), 3 Darren Bravo, 4 Marlon Samuels, 5 Shimron Hetmyer, 6 Rovman Powell (capt), 7 Roston Chase, 8 Keemo Paul, 9 Devendra Bishoo, 10 Kemar Roach, 11 Oshane Thomas\n\nBangladesh have made five changes to their side, bringing in Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman, Mehidy Hasan Miraz and Rubel Hossain.'],
#   [0.4404,
#    '<strong>Bangladesh:</strong> 1 Tamim Iqbal, 2 Liton Das, 3 Imrul Kayes, 4 Soumya Sarkar, 5 Mushfiqur Rahim (wk), 6 Shakib Al Hasan, 7 Mahmudullah, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\n<strong>West Indies:</strong> 1 Kieran Powell, 2 Shai Hope (wk), 3 Darren Bravo, 4 Marlon Samuels, 5 Shimron Hetmyer, 6 Rovman Powell (capt), 7 Roston Chase, 8 Keemo Paul, 9 Devendra Bishoo, 10 Kemar Roach, 11 Oshane Thomas\n\nBangladesh have made five changes to their side, bringing in Shakib Al Hasan, Tamim Iqbal, Mustafizur Rahman, Mehidy Hasan Miraz and Rubel Hossain.'],
#   [0.0,
#    'And in the meantime, you can apprise yourself by reading <a href="http://www.espncricinfo.com/series/18783/preview/1153314/bangladesh-vs-west-indies-1st-odi-wi-in-bangladesh-2018-19" target="_blank">Mohammad Isam\'s preview</a> for the game.Over the wicket to the right-handerSpin from both ends, here\'s Shakib, around the wicketOver the wicket now for PowellShuvo Shafiqur : "The color of this wicket reminds me of earlier BNS days.'],
#   [0.0, '"Shakib Al Hasan now.'],
#   [0.3919,
#    "But here comes Soumya Sarkar, unfamiliar position at No.6 but Bangladesh are well set despite Shakib's wicket"],
#   [0.6369,
#    'Liton played a nice knock, Shakib got some quick runs, that helped a lot.'],
#   [0.0,
#    'Liton Das made 41 before throwing it away but Shakib Al Hasan made a breezy 30.'],
#   [0.0,
#    '"Two slips and a wide gully for Shakib.TareQ: "Now that\'s going to be a real test for Shakib al hasan when he come down the crease at 3rd over.'],
#   [0.0,
#    'Shakib and Tamim doing superbly in their century stand after that early wicket.'],
#   [0.4019,
#    'Ferdous C: "Shakib is bit tentative in 1st few overs, one he get passed this stage he is a treat to watch.'],
#   [0.1531,
#    'The Man of the Match today is <b>Tamim Iqbal</b>, denying Shakib Al Hasan a hat-trick of awards.'],
#   [0.7579, 'Shakib played great and so did Mushfiqur.'],
#   [0.2732,
#    'Tamim and Shakib were brilliant and we although we did lose a bunch of wickets in the middle, our Nos.'],
#   [0.6124,
#    "As a Bangladeshi fan, I wish Shakib can break another Bengali Saurav Ganguli's record."],
#   [-0.0516,
#    'Shakib to continueMustafa Moudi: "Shakib tried hard to come closer in the Career Wickets to Mortaza, But even Mortaza is adamant to keep the gap unchanged.'],
#   [-0.3586,
#    '"Hasib: "Although Shakib missed the hat trick but he might not miss the \'Man of the Match\' Hat trick!!!'],
#   [-0.1935,
#    '"Simgwat: "If Solomon Mire is going to have a long career he needs to learn temperament, his application especially rotating the strike and his choices"Shakib will be on a hat-trick when he returns for the next over.'],
#   [0.34,
#    'FixedArsalan: "The greatness of Shakib is highlighted by the fact that he would easily make it into this side or most other sides, either purely as a batsman or a bowler.'],
#   [0.0,
#    'BD is without their key bowler in Shakib, so they will need some runs on the board to defend.'],
#   [0.0,
#    'Mashrafe Mortaza has got the new ball.Mehidy Hasan from the other endAround the wicketBack to around the wicket to the left-handerAround the wicket'],
#   [0.296,
#    'Bangladesh are a different force in limited-overs cricket, they beat New Zealand in the Champions Trophy in 2017, but they are without the Man of the Match from that game - Shakib Al Hasan.'],
#   [0.128,
#    'back in the runs "<br><br>Ashis : "Injury of Shakib has made BD bowling look like a club team\'s attack especially when there are two RHB in the middle...everyone can easily feel the importance of Shakib.'],
#   [0.4404,
#    "It's a 'Eid day' (Biggest Festiva) in Bangladesh and I we are eagerly waiting for another gigantic victory in the eve of Shakib Al Hasan's landmark 200th ODI."],
#   [0.4215,
#    '<strong>Bangladesh:</strong> Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>New Zealand:</strong>: Martin Guptill, Colin Munro, Kane Williamson (capt), Ross Taylor, Tom Latham (wk), James Neesham, Colin de Grandhomme, Mitchell Santner, Matt Henry, Lockie Ferguson, Trent Boult\n\n<strong>Mashrafe</strong>: Would have liked to bowl.'],
#   [0.4798,
#    "Thus took al sort of measures so that cannot deprive of watching Shakib Al Hasan's landmark match."],
#   [0.6124,
#    'Santner did well which gives hope to the Bangladeshi spinners especially Shakib and Mehidy. "'],
#   [-0.631,
#    'Shakib top-scored with 64 in his 200th ODI, but there were also five batsmen who got into the 20s, and then got out.'],
#   [0.5574,
#    '"Leonardo : "Just as I was about to say Bangladesh may well be on course to best their highest ever ODI total, they lose Hasan, I however think they still can."'],
#   [0.4404,
#    '"Shakib now\n\nDanish Tanveer: "Forget about the crystal ball, New Zealand gonna win this match by 7 wickets and I\'m looking forward to see England vs New Zealand in the final"In ODIs - Munro v Shakib: 34 runs off 21 balls, 0 dismissals; Guptill v Shakib: 42 off 55, 3 dismissals.'],
#   [0.4404,
#    '"Shakib now\n\nDanish Tanveer: "Forget about the crystal ball, New Zealand gonna win this match by 7 wickets and I\'m looking forward to see England vs New Zealand in the final"In ODIs - Munro v Shakib: 34 runs off 21 balls, 0 dismissals; Guptill v Shakib: 42 off 55, 3 dismissals.'],
#   [0.3818, "It's clear who Shakib would rather bowl toslip and a short leg"],
#   [-0.4158,
#    "Not a very wise decision to use Soumya's part timers to cover Shakib's 10 overs."],
#   [0.0, 'Hasan Ali.Junaid now, from left-arm round.'],
#   [-0.4767,
#    "6<b>Breaking news:</b> Shakib Al Hasan is flying home due to his finger injury.Shaheen over the wicket, with a slip in placearound the wicket to MushiKayes pulls out while Hasan's running in."],
#   [-0.4767,
#    "6<b>Breaking news:</b> Shakib Al Hasan is flying home due to his finger injury.Shaheen over the wicket, with a slip in placearound the wicket to MushiKayes pulls out while Hasan's running in."],
#   [0.1531,
#    "They lost their best batsman Tamim in the 1st match, lost Shakib before today's virtual semi-final."],
#   [-0.6688,
#    'Mashrafe to continue, round the wicket to Imam.GG: "Now that Shakib is not playing, where will Ban get those 10 overs from!"'],
#   [-0.4215,
#    '<a href="http://www.espncricinfo.com/story/_/id/24802439/injured-shakib-al-hasan-flies-home-being-ruled-asia-cup" target="_blank">The latest</a> on Shakib Al Hasan\'s injury, for those who just tuned in.Mashrafe\'s been holding the back of his right thigh every now and then.'],
#   [0.0,
#    '-- If you haven\'t heard already, Shakib Al Hasan is <a href="http://www.espncricinfo.com/story/_/id/24802439/injured-shakib-al-hasan-flies-home-being-ruled-asia-cup" target="_blank">out injured</a>.'],
#   [0.0,
#    '<b>Bangladesh XI</b>: 1 Tamim Iqbal, 2 Mohammad Mithun, 3 Shakib Al Hasan, 4 Mushfiqur Rahim (wk), 5 Mahmudullah, 6 Sabbir Rahman, 7 Mohammad Saifuddin, 8 Mehidy Hasan Miraz, 9 Mashrafe Mortaza (capt), 10 Mustafizur Rahman, 11 Rubel Hossain\n\nOne change for Sri Lanka: Shehan Madushanka replaces Lakshan Sandakan.'],
#   [0.0,
#    '<b>International debut for Shehan Madhushanka.</b>\n\n<b>Sri Lanka XI</b>: 1 Upul Tharanga, 2 Danushka Gunathilaka, 3 Kusal Mendis, 4 Dinesh Chandimal (capt), 5 Niroshan Dickwella (wk), 6 Asela Gunaratne, 7 Thisara Perera, 8 Akila Dananjaya, 9 Suranga Lakmal, 10 Dushmantha Chameera, 11 Shehan Madushanka\n\nShaon: "Shakib goes to SRH for 2 crore inr."'],
#   [0.0, 'Shakib Al Hasan.'],
#   [-0.4019,
#    'In a day and age where 280\'s are considered par Sri Lanka never seem to get the right approach to even reach 250"Javed Khan Shai: "Hey Akshay, any update about Shakib\'s injury? "'],
#   [-0.5719,
#    'Kamruzzaman Rez: "Expected that Shakib will back with no doubt and make history of achieving Tri-Nations Cup for Bangladesh."'],
#   [0.0,
#    '"Given Dhaka\'s traffic, Shakib may not be back by the time of the presentation ceremony.'],
#   [0.2023,
#    '<b>Update: Shakib taken to hospital for a scan on his finger</b>Anuruddha : "I see Asela Gunaratne is playing his final ODI.'],
#   [-0.296,
#    'We will have an update on Shakib shortly.Dushmantha Chameera<b>Still no update on Shakib.'],
#   [-0.5023,
#    'Bangladesh unfortunately lost Shakib Al Hasan to injury, but even without him, this was a shoddy and listless batting performance.'],
#   [-0.4767, 'Hearing that Shakib could be out of the first Test.'],
#   [0.7351,
#    'jamal: "@Akshay: Think one of the only player in the BD lineup who does have the temperament to play and win matches for any country is Shakib.'],
#   [0.0, 'Nasim: "Is there any update about Shakib\'s injury???? "'],
#   [0.0,
#    'Not yet<b>Shakib Al Hasan is back in the Bangladesh dressing room with his left arm in a sling.'],
#   [-0.4215,
# ...
#   [0.6249,
#    'On his feet now.Ayush Kapoor: "Mithun has showed great composure in both of his inning.'],
#   [0.6124,
#    'Our top order has to step up little bit, Mithun has been scoring well, Mustafizur bowled well today.'],
#   [0.0,
#    'They have dropped Mohammad Mithun, Nazmul Islam, Mohammad Saifuddin, Abu Hider and Ariful Haque from their third ODI against Zimbabwe in October.'],
#   [-0.0111,
#    '"<br><bR>Pranand: "Must win for ZIM as last match but its difficult"<br><br>\n\nZimbabwe are continuing with the same line-up; Bangladesh have made one change, bringing back Sunzamul Islam to replace Mohammad Saifuddin.<br>\n\n\n\n<b>Cremer:</b> Not sure actually [if we\'d have batted first].'],
#   [0.3182, '"khan: "day by day, i am becoming a fan of Mithun.'],
#   [0.5256,
#    'Soumya was timing the ball very sweetly early on, and later on Mithun revived the ship along with Saifuddin with a century stand from 131 for 7 to take them past 200.'],
#   [0.4215,
#    '<strong>Bangladesh:</strong> Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>New Zealand:</strong>: Martin Guptill, Colin Munro, Kane Williamson (capt), Ross Taylor, Tom Latham (wk), James Neesham, Colin de Grandhomme, Mitchell Santner, Matt Henry, Lockie Ferguson, Trent Boult\n\n<strong>Mashrafe</strong>: Would have liked to bowl.'],
#   [0.0,
#    'Mohammad Isam and Sidharth Monga are our reporters at the venue today.'],
#   [0.7096,
#    'naser: "Mithun has yet to play a match winnings innings for bangladesh.'],
#   [-0.3724,
#    '<b>Pakistan:</b> Fakhar Zaman, Imam Ul Haq, Babar Azam, Sarfraz Ahmed (c, wk), Shoaib Malik, Asif Ali, Shadab Khan, Mohammad Nawaz, Hasan Ali, Junaid Khan, Shaheen Shah Afridi\n\n<b>Bangladesh:</b> Liton Das, Soumya Sarkar, Mohammad Mithun, Mushfiqur Rahim (wk), Mominul Haque, Imrul Kayes, Mahmudullah, Mashrafe Mortaza (c), Mehidy Hasan, Rubel Hossain, Mustafizur Rahman\n\nInteser: "Shakib not playing is a huge blow.'],
#   [-0.4019,
#    'Mohammad Isam\'s <a href="http://www.espncricinfo.com/story/_/id/24792115/two-unpredictable-teams-gear-knockout-encounter" target="_blank">match preview has more.</a> \n\nWaseem Sarwar: "Pakistan won\'t be going home even if they lose this match.'],
#   [0.2732, 'No slip.Chirag Sheth: "Kudos to Mushfiqur & Mithun.'],
#   [0.0, 'Mohammad Mithun.'],
#   [0.6124, 'And Mithun batted brilliantly too.'],
#   [0.2498,
#    'Rohan Trehan: "Mushfiqur may be MOTM but lets not forget Mithun\'s contribution.'],
#   [-0.4767,
#    'Anamul Haque, Nasir Hossain and Abul Hasan are out; Mohammad Mithun, Saifuddin and Mehidy are in.'],
#   [-0.1779,
#    '<a href="http://www.espncricinfo.com/story/_/id/24688174/extreme-training-helps-mushfiqur-conquer-extreme-conditions" target="_blank"><b>For more on that</b></a></b>, here is Mohammad Isam.<br><br>\n\nThere can be no other reason for India bowling first besides their eagerness to unleash their secret weapon - <b>Kedar Jadhav</b>.'],
#   [0.0,
#    '"<br><br>\n\n<b>Bangladesh:</b> Liton Das, Soumya Sarkar, Mohammad Mithun, Mushfiqur Rahim (wk), Imrul Kayes, Mahmudullah, Mehidy Hasan, Mashrafe Mortaza (capt.'],
#   [0.205,
#    '<strong>Teams</strong> - <strong>Bangladesh: </strong>Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>South Africa:</strong> Quinton de Kock (wk), Aiden Markram, Faf du Plessis (c), Rassie van der Dussen, David Miller, JP Duminy, Andile Phehlukwayo, Chris Morris, Kagiso Rabada, Lungi Ngidi, Imran Tahir\n\n<strong>Faf du Plessis</strong>: "We\'re playing the extra seamer today so we want to try and attack Bangladesh with some extra pace.'],
#   [0.0, 'They could have included him instead of Mithun.'],
#   [0.0,
#    'Mohammad Isam is at the Oval for us today: "A Bangladesh majority among the spectators, they are slowly coming in.'],
#   [-0.4767, 'Mohammad Saifuddin into the attack'],
#   [0.4215,
#    'Mohammad Saifuddin, playing in only his second ODI, picked three wickets to play a key role in bottling up pressure and scything through with the wickets after Brendan Taylor top scored with 75.'],
#   [-0.0572, "I don't want Mithun to open."],
#   [0.6124,
#    'Shahin Newaz: "Saifuddin is a poor change in place of rubel... Rubel has the knack of bowling quick in a good length on a consistent basis where as saifuddin is more of a change of pace bowler..."\n\nSazedur Rahman: "I would love to see Mithun instead of Imrul, and Saifuddin instead of Rubel.'],
#   [0.3818,
#    "Mohammad Mithun comes in for Imrul Kayes, and Mohammad Saifuddin replaces Rubel Hossain.<br><br>\n\nWell well, here's a bit of a shocker."],
#   [0.3818,
#    "Mohammad Mithun comes in for Imrul Kayes, and Mohammad Saifuddin replaces Rubel Hossain.<br><br>\n\nWell well, here's a bit of a shocker."],
#   [0.4215, 'I think Mithun should get another opportunity in his place.'],
#   [0.5927,
#    "Mohammad Mithun's 63 now seems ages ago, but without that 131-run partnership, Bangladesh would surely have crumbled."],
#   [0.5927,
#    "Mohammad Mithun's 63 now seems ages ago, but without that 131-run partnership, Bangladesh would surely have crumbled."],
#   [0.1016,
#    'Were were under pressure very early, but credit goes to Mithun, and he took the pressure away from me.'],
#   [-0.8519,
#    "And also Mithun was out at the wrong time, and we could've made 280-290 if he wasn't out."],
#   [0.1531,
#    "We didn't get the start we wanted, but credit to Mithun for taking the pressure away from me."],
#   [0.0, 'Mohammad Saifuddin has the new ball.']],
#  'mohammad saifuddin': [[-0.6636,
#    'I feel BD missed a trick by not giving Saifuddin another match.'],
#   [0.2714,
#    'We\'re all set\n\nOur US readers can watch the match <a href="http://www.espn.com/watch?id=51ea082b-6199-4b02-a9c6-449e1f909bc9" target="_blank">LIVE HERE</a>\n\n<strong>Liton Das to keep wickets for Bangladesh</strong>\n\nNew Zealand XI: Guptill, Nicholls, Munro, Taylor, Latham (Capt), de Grandhomme, Neesham, Santner, Ferguson, Boult, Southee\n\nBangladesh XI: Tamim, Liton (wk), Soumya Sarkar, Mushfiqur, Mahmudullah, Sabbir, Mehidy Hasan Miraz, Saifuddin, Mashrafe (capt), Rubel, Mustafizur\n\nRadwoan : "Rubel In for Mithun means Bangladesh playing with five bowlers!'],
#   [-0.8614,
#    'Mohammad Isam has more <a href="http://www.espncricinfo.com/series/18805/preview/1153846/new-zealand-vs-bangladesh-3rd-odi-bangladesh-in-nz-2018-19" target="_blank">in his preview.</a>\n\nBangaladesh will be without their best batsman of the series, Mohammad Mithun, out with an injury, and Mushfiqur Rahim is a doubtful starter as well.'],
#   [-0.2755, 'Mohammad Isam: "Can\'t agree with you, AJ.'],
#   [-0.4767,
#    'And as Isam hinted earlier, Saifuddin sits out and Abu Jayed gets a game.'],
#   [-0.4767,
#    '<a href="http://www.espncricinfo.com/series/11122/preview/1168512/bangladesh-vs-west-indies-5th-match-ireland-tri-series" target="_blank">Here\'s the preview of the game from Mohammad Isam</a>, who by the way has more match-related news "<strong>Mohammad Saifuddin</strong> is suffering from a <strong>back injury</strong>, in addition to his tennis elbow.'],
#   [0.0,
#    "Mohammad Isam will finally have something to write about Bangladesh's decent batting on tour, I'd imagine.The players are cooling off for drinks."],
#   [0.0,
#    'Mohammad Isam tried some permutations and combinations <a href="http://www.espncricinfo.com/series/8532/preview/1153248/afghanistan-vs-bangladesh-6th-match-group-b-asia-cup" target="_blank">in the preview</a>.'],
#   [0.0,
#    "Even though Mehidy is on 16 off 18, Isam believes Saifuddin should bat above himMehidy's shot selection proves why Isam wanted Saifuddin batting above MehidyFerguson comes backOne slip in placeAround the wicket to Saifuddin"],
#   [0.2846,
#    "Mohammad Mithun came to the rescue yet again but the batsmen before him will have to take more responsibility going forward, especially in Shakib's absence."],
#   [0.296, 'Shoaib : "Saifuddin has complicated matters by batting Well.'],
#   [0.0,
#    'They have dropped Mohammad Mithun, Nazmul Islam, Mohammad Saifuddin, Abu Hider and Ariful Haque from their third ODI against Zimbabwe in October.'],
#   [-0.0111,
#    '"<br><bR>Pranand: "Must win for ZIM as last match but its difficult"<br><br>\n\nZimbabwe are continuing with the same line-up; Bangladesh have made one change, bringing back Sunzamul Islam to replace Mohammad Saifuddin.<br>\n\n\n\n<b>Cremer:</b> Not sure actually [if we\'d have batted first].'],
#   [0.765,
#    'imTurin: "220 will be a par score...if Bangladesh able to make it, they will win it comfortably..."Mursalin Sunny: "We\'ve always heard of Saifuddin as an all-rounder.'],
#   [0.0,
#    'He ended with 144 off 140 with 13 fours and six sixes, while Saifuddin too hit his maiden ODI fifty.'],
#   [0.6249,
#    'Imrul Kayes played the innings of his life to make 144, and with support from Saifuddin haled them past 270.'],
#   [0.0,
#    'Saadat Saquib: "Bangladesh coach was saying about Saifuddin to be next Mashrafe.'],
#   [0.0, "Here's MahmudullahAnother change - Saifuddin comes back"],
#   [0.5409,
#    'Just over a third of his career ODI runs are in boundaries.. " --- I suppose the argument here is that he\'s a compact, organised player who is playing the merit of the ball, which is not always optimal in Powerplays<br><br>nathan : "exactly @ brendan j thats what Andy means he either hits boundary or blocks, he needs to think more about the ones and twos "<br><br>james: "To Saifuddin\'s credit, he bowled exceptionally well throughout the BPL, with some very good death bowling as well.'],
#   [0.0253,
#    'This one is an easier chase too and not as strong a bowling attackRj SAAD: "Mohammad Saifuddin was looking too composed in BPL with his Yorkers, slow balls and length balls.'],
#   [0.4939,
#    '"Some of those incoming deliveries from Saifuddin looked pretty sharp and accurateA slip for TaylorTime for a change - here\'s Mustafizur.'],
#   [0.4215,
#    '<strong>Bangladesh:</strong> Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>New Zealand:</strong>: Martin Guptill, Colin Munro, Kane Williamson (capt), Ross Taylor, Tom Latham (wk), James Neesham, Colin de Grandhomme, Mitchell Santner, Matt Henry, Lockie Ferguson, Trent Boult\n\n<strong>Mashrafe</strong>: Would have liked to bowl.'],
#   [0.0,
#    'Mohammad Isam and Sidharth Monga are our reporters at the venue today.'],
#   [-0.4019,
#    'Mohammad Isam\'s <a href="http://www.espncricinfo.com/story/_/id/24792115/two-unpredictable-teams-gear-knockout-encounter" target="_blank">match preview has more.</a> \n\nWaseem Sarwar: "Pakistan won\'t be going home even if they lose this match.'],
#   [0.0, 'Mohammad Mithun.'],
#   [-0.1779,
#    '<a href="http://www.espncricinfo.com/story/_/id/24688174/extreme-training-helps-mushfiqur-conquer-extreme-conditions" target="_blank"><b>For more on that</b></a></b>, here is Mohammad Isam.<br><br>\n\nThere can be no other reason for India bowling first besides their eagerness to unleash their secret weapon - <b>Kedar Jadhav</b>.'],
#   [0.205,
#    '<strong>Teams</strong> - <strong>Bangladesh: </strong>Tamim Iqbal, Soumya Sarkar, Shakib Al Hasan, Mushfiqur Rahim (wk), Mohammad Mithun, Mahmudullah, Mosaddek Hossain, Mohammad Saifuddin, Mehedi Hasan, Mashrafe Mortaza (c), Mustafizur Rahman\n\n<strong>South Africa:</strong> Quinton de Kock (wk), Aiden Markram, Faf du Plessis (c), Rassie van der Dussen, David Miller, JP Duminy, Andile Phehlukwayo, Chris Morris, Kagiso Rabada, Lungi Ngidi, Imran Tahir\n\n<strong>Faf du Plessis</strong>: "We\'re playing the extra seamer today so we want to try and attack Bangladesh with some extra pace.'],
#   [0.0,
#    'Mohammad Isam is at the Oval for us today: "A Bangladesh majority among the spectators, they are slowly coming in.'],
#   [-0.4767, 'Mohammad Saifuddin into the attack'],
#   [0.5994,
#    'Just before Saifuddin\'s delivery, one guy just said: "come on Saifuddin, this is your do-or-die over"Avnish Anshu: "It is situations like these that make me understand why AB Devilliers said he would play MSD even if he was in a wheelchair.'],
#   [0.5994,
#    'Just before Saifuddin\'s delivery, one guy just said: "come on Saifuddin, this is your do-or-die over"Avnish Anshu: "It is situations like these that make me understand why AB Devilliers said he would play MSD even if he was in a wheelchair.'],
#   [-0.4767, '"Mohammad Saifuddin is back into the attack'],
#   [0.1531,
#    "They will need a solid middle order batsmen, and then if they do need a batsmen with pace, they'll look at Saifuddin."],
#   [0.4215,
#    'Mohammad Saifuddin, playing in only his second ODI, picked three wickets to play a key role in bottling up pressure and scything through with the wickets after Brendan Taylor top scored with 75.'],
#   [0.6124,
#    'Shahin Newaz: "Saifuddin is a poor change in place of rubel... Rubel has the knack of bowling quick in a good length on a consistent basis where as saifuddin is more of a change of pace bowler..."\n\nSazedur Rahman: "I would love to see Mithun instead of Imrul, and Saifuddin instead of Rubel.'],
#   [0.4754,
#    'Mithun will give more strength in middle order while Saifuddin can hit the ball hard at the end part of the innings.'],
#   [0.3818,
#    "Mohammad Mithun comes in for Imrul Kayes, and Mohammad Saifuddin replaces Rubel Hossain.<br><br>\n\nWell well, here's a bit of a shocker."],
#   [0.3818,
#    "Mohammad Mithun comes in for Imrul Kayes, and Mohammad Saifuddin replaces Rubel Hossain.<br><br>\n\nWell well, here's a bit of a shocker."],
#   [-0.5106,
#    '"hashanat: "I believe Abu Haider Rony is also there as a good medium pace all-rounder with Saifuddin@Amzad "Bangladesh have lifted their run-rate to six now and these two are looking ominousChase has been hit out of the attack.'],
#   [0.8957,
#    "<strong>1:41pm</strong> Bangladesh had a comfortable win in the second ODI a couple of days ago thanks to a fine bowling performance from Mohammad Saifuddin, who removed some of the key Zimbabwe batsmen and never allowed the vistors' innings take any momentum."],
#   [0.0,
#    '- Your thoughts on Saifuddin?Shahriar: "Debayan do you think Bangladesh is a favourite in the next World Cup ?"'],
#   [0.8074,
#    '"These two have added 45 off 29 nowSubhayan: "Would love to see another thrilling match ending in a tie - A Neutral Fan"Amir: "I think Mash was adjusting so that Saifuddin bowls the last over.'],
#   [-0.2023,
#    '<b>11.38am</b> Bangladesh have picked Mohammad Saifuddin to replace Sunzamul Islam in a bid to further strengthen the pace attack.'],
#   [0.5927,
#    "Mohammad Mithun's 63 now seems ages ago, but without that 131-run partnership, Bangladesh would surely have crumbled."],
#   [0.0, 'Mohammad Saifuddin has the new ball.']],
#  'mosaddek hossain': [[-0.4019,
#    'Slip, gully, short leg and leg slip around him.Just got word that <b>if Bangladesh bowl Zimbabwe out for less than 172</b>, they\'ll pick up another bonus point.Zahid Hossain: "Phil Simmons bowled 8 maidens out of 10 in an ODI against Pakistan.'],
#   [0.2244,
#    'I guess he\'s still struggling with that cramp.Rubel Hossain: "I\'ll take the winning wicket!"'],
#   [0.5859,
#    '<a href="http://www.thecricketmonthly.com/story/1166523/javed-omar--no--yes--sorry" target="_blank">Here is the link</a> "\n\nAllen nowZahid Hossain: "@Muzammil: interesting stats- Tamim against Bermuda, Canada and the Netherlands: 5 matches, 25 runs, average 5.00, strike rate 42.37 Tamim against Australia, England, Pakistan, South Africa, India, Srilanka, West Indies, New Zealand: 128 matches, 4197 runs, average 34.97, strike rate 79.14 "<b>Injury update from West Indies\' twitter account:</b> Both Shai Hope and Kemar Roach will play no further part in this 3rd ODI.']]}
